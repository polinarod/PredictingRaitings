# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn import model_selection as ms
from scipy.stats import pearsonr
from sklearn.metrics import make_scorer
from sklearn import metrics

from sklearn.neighbors import KNeighborsRegressor


from warnings import simplefilter

rand_st=4
#simplefilter("ignore")

# %%
#output=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\results.xlsx')
output=pd.read_excel(r'C:\Users\vznam\Downloads\PredictingRatings-master\models\results.xlsx')
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  186.539067  234.559134
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  189.358443  237.420124
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  175.593949  221.353796
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  176.326439  221.767050
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  177.431734  224.595199
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  182.048649  228.384992
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  192.062805  241.580990
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  193.242293  242.404488
# 8   LinearRegression(copy_X=True, fit_intercept=Tr...  171.079101  215.522294
# 9   LinearRegression(copy_X=True, fit_intercept=Tr...  150.700896  192.272077
# 10  LinearRegression(copy_X=True, fit_intercept=Tr...  342.160735  431.049943
# 11  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 12  ExtraTreesRegressor(bootstrap=False, criterion...  148.851787  190.514633
# 13  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 14  KNeighborsRegressor(algorithm='auto', leaf_siz...  445.442198  562.134243
# 15  KNeighborsRegressor(algorithm='auto', leaf_siz...  186.072970  236.294144
# 16  RandomForestRegressor(bootstrap=False, criteri...  352.305849  444.982165
# 17  RandomForestRegressor(bootstrap=True, criterio...  164.729359  206.729387
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.486111             0.367
# 1                    0.483303             0.367
# 2                    0.453718             0.164
# 3                    0.461520             0.269
# 4                    0.464714             0.151
# 5                    0.451721             0.142
# 6                    0.467338             0.151
# 7                    0.461618             0.165
# 8                    0.461243             0.370
# 9                    0.574320             0.362
# 10                   0.461242             0.430
# 11                   0.434467          4237.236
# 12                   0.587816          4247.091
# 13                   0.434467          4306.235
# 14                   0.134894             0.500
# 15                   0.333543             0.999
# 16                   0.398389           216.097
# 17                   0.548366            58.591
#
#                                           Комментарий
# 0   Обучение на полном набооре -> прогноз рейтинго...
# 1   Обучение на полном набооре -> прогноз рейтинго...
# 2   Обучение только на победах белых -> прогноз ре...
# 3   Обучение только на победах черных -> прогноз р...
# 4   Обучение только на ничьих -> прогноз ретйтинга...
# 5   Обучение только на ничьих -> прогноз ретйтинга...
# 6   Обучение только на проигрышах белых -> прогноз...
# 7   Обучение только на проигрышах черных -> прогно...
# 8                             Обучение на среднем ЭЛО
# 9                      Обучение на разнице в рейтинге
# 10                        Обучение на сумме рейтингов
# 11             ExtraTreesRegressor по сумме рейтингов
# 12          ExtraTreesRegressor на разнице в рейтинге
# 13             ExtraTreesRegressor по сумме рейтингов
# 14             KNeighborsRegressor по сумме рейтингов
# 15          KNeighborsRegressor на разнице в рейтинге
# 16                    RandomForest по сумме рейтингов
# 17                 RandomForest на разнице в рейтинге

# %%
#elos=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\clean_elos.csv')
elos=pd.read_csv(r'C:\Users\vznam\Downloads\PredictingRatings-master\data\clean_elos.csv')
elos.head()
# Out:
#    WhiteElo  BlackElo  MeanElos  DiffElos  SumElos
# 0      2354      2411      2382       -57     4765
# 1      1915      1999      1957       -84     3914
# 2      2446      2191      2318       255     4637
# 3      2168      2075      2121        93     4243
# 4      2437      2254      2345       183     4691

# %%
#features=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features.csv')
features=pd.read_csv(r'C:\Users\vznam\Downloads\PredictingRatings-master\data\features.csv')

print(features.info())
print(features.shape)
features.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24255 entries, 0 to 24254
# Columns: 233 entries, Result to InsufficientMaterial
# dtypes: float64(111), int64(122)
# memory usage: 43.1 MB
# None
# (24255, 233)
#              Result      NumMoves     MeanScore     ModeScore    FinalScore  \
# count  24255.000000  24255.000000  24255.000000  24255.000000  24255.000000
# mean       0.544877     42.252690     30.881103     11.907442    111.901711
# std        0.417736     16.235593    233.709202    445.214702   2310.851869
# min        0.000000     10.000000  -2162.262500 -11447.000000 -12261.000000
# 25%        0.000000     31.000000    -60.758665      0.000000   -362.000000
# 50%        0.500000     40.000000     24.563636      0.000000      0.000000
# 75%        1.000000     51.000000    123.987715     26.000000    546.500000
# max        1.000000    165.000000   2073.289256  11259.000000  12337.000000
#
#           FullMoves      MinScore      MaxScore   MedianScore      StdScore  \
# count  24255.000000  24255.000000  24255.000000  24255.000000  24255.000000
# mean      83.967223   -794.591878    988.643950     68.913894    314.678490
# std       32.489872   2126.099646   2275.840558     64.170646    475.478471
# min       19.000000 -12348.000000    -51.000000      0.000000      7.795716
# 25%       61.000000   -482.000000     67.000000     30.000000     61.336328
# 50%       79.000000    -75.000000    156.000000     49.000000    145.621548
# 75%      102.000000    -18.000000    700.000000     84.000000    291.317992
# max      329.000000     26.000000  12352.000000    784.000000   3962.575036
#
#                ...                   EndB         EndR     EndK   WhiteСhecks  \
# count          ...           24255.000000  24255.00000  24255.0  24255.000000
# mean           ...               0.631293      1.03892      1.0      2.015584
# std            ...               0.676858      0.74847      0.0      2.874868
# min            ...               0.000000      0.00000      1.0      0.000000
# 25%            ...               0.000000      0.00000      1.0      0.000000
# 50%            ...               1.000000      1.00000      1.0      1.000000
# 75%            ...               1.000000      2.00000      1.0      3.000000
# max            ...               2.000000      2.00000      1.0     71.000000
#
#        WhiteQueenCastle  BlackQueenCastle     Promotion     EnPassant  \
# count      24255.000000      24255.000000  24255.000000  24255.000000
# mean           1.457308          0.910740      0.064069      0.061637
# std            4.179615          3.663225      0.291749      0.245589
# min            0.000000          0.000000      0.000000      0.000000
# 25%            0.000000          0.000000      0.000000      0.000000
# 50%            0.000000          0.000000      0.000000      0.000000
# 75%            0.000000          0.000000      0.000000      0.000000
# max           35.000000         36.000000      4.000000      2.000000
#
#        CanClaimDraw  InsufficientMaterial
# count  24255.000000          24255.000000
# mean       0.035415              0.000783
# std        0.184831              0.027978
# min        0.000000              0.000000
# 25%        0.000000              0.000000
# 50%        0.000000              0.000000
# 75%        0.000000              0.000000
# max        1.000000              1.000000
#
# [8 rows x 233 columns]

# %%
target_white=elos['WhiteElo']
target_black=elos['BlackElo']
target_mean=elos['MeanElos']
target_diff=elos['DiffElos']
target_sum=elos['SumElos']

# %%
X_train_sum, X_test_sum, Y_train_sum, Y_test_sum =ms.train_test_split(features, target_sum, test_size = 0.3,random_state=rand_st)
print ('Train data size: {} instances \nTest data size: {} instances'.format(len(X_train_sum), len(Y_train_sum)))
print(X_train_sum.shape)
print(Y_train_sum.shape)
print(X_test_sum.shape)
print(Y_test_sum.shape)
# Out:
# Train data size: 16978 instances
# Test data size: 16978 instances
# (16978, 233)
# (16978,)
# (7277, 233)
# (7277,)

# %%
X_train_diff, X_test_diff, Y_train_diff, Y_test_diff =ms.train_test_split(features, target_diff, test_size = 0.3,random_state=rand_st)
print ('Train data size: {} instances \nTest data size: {} instances'.format(len(X_train_diff), len(Y_train_diff)))
print(X_train_diff.shape)
print(Y_train_diff.shape)
print(X_test_diff.shape)
print(Y_test_diff.shape)
# Out:
# Train data size: 16978 instances
# Test data size: 16978 instances
# (16978, 233)
# (16978,)
# (7277, 233)
# (7277,)

# %% [markdown]
# #### Для теста

# %%
target_sum1=target_sum[:5000]
features1=features[:5000]
X_train_sum1, X_test_sum1, Y_train_sum1, Y_test_sum1 =ms.train_test_split(features1, target_sum1, test_size = 0.3,random_state=rand_st)
print ('Train data size: {} instances \nTest data size: {} instances'.format(len(X_train_sum1), len(Y_train_sum1)))
print(X_train_sum1.shape)
print(Y_train_sum1.shape)
print(X_test_sum1.shape)
print(Y_test_sum1.shape)
# Out:
# Train data size: 3500 instances
# Test data size: 3500 instances
# (3500, 233)
# (3500,)
# (1500, 233)
# (1500,)

# %%
target_diff2=target_diff[:5000]
features2=features[:5000]
X_train_diff2, X_test_diff2, Y_train_diff2, Y_test_diff2 =ms.train_test_split(features2, target_diff2, test_size = 0.3,random_state=rand_st)
print ('Train data size: {} instances \nTest data size: {} instances'.format(len(X_train_diff2), len(Y_train_diff2)))
print(X_train_diff2.shape)
print(Y_train_diff2.shape)
print(X_test_diff2.shape)
print(Y_test_diff2.shape)
# Out:
# Train data size: 3500 instances
# Test data size: 3500 instances
# (3500, 233)
# (3500,)
# (1500, 233)
# (1500,)

# %%
def predictions_report(pred_target,predictions):
    mae_report=mae(pred_target,predictions)
    print ('MAE = {:.3f}'.format(mae_report))
    
    rmse_report = (mse(pred_target, predictions))**0.5
    print ('RMSE = {:.3f}'.format(rmse_report))
    
    corr_coef = pearsonr(pred_target,predictions)
    print("Correlation coefficient = {:.3f}".format(corr_coef[0]))
    
    return (mae_report,rmse_report,corr_coef)

# %%
def GridTune_sum(params,classifiers,folds):
    mae = make_scorer(metrics.mean_absolute_error)
   
    grid = ms.GridSearchCV(classifiers,
                           params,
                           refit=True,  
                           scoring=mae,
                           n_jobs=-1,
                           cv=ms.StratifiedKFold(n_splits=folds))

    '''train_X_data='X_train_'+mode
    train_Y_data='Y_train_'+mode'''
    
    grid_best_model = grid.fit(X_train_sum1,Y_train_sum1)

    print("Лучшие параметры для MAE:")
    print(grid_best_model.best_params_)
    print('\nЛучший алгоритм:')
    print(grid_best_model.best_estimator_)
    return grid_best_model

# %%
kn_sum_params =[{'n_neighbors':[2,5,10,15],
                'metric':['chebyshev','manhattan'],
                'leaf_size':[15,30,50]}]

start_kn_sum = time.time()

kn_sum1=KNeighborsRegressor(n_jobs=-1,weights='distance',algorithm='auto',)
kn_sum_model1=GridTune_sum(kn_sum_params,kn_sum1,5)
kn_sum_predictions1=kn_sum_model1.predict(X_test_sum1)

scores_kn_sum1=predictions_report(Y_test_sum1,kn_sum_predictions1)
full_time_kn_sum=round(time.time() - start_kn_sum,3)
print(full_time_kn_sum, 'c')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Лучшие параметры для MAE:
# {'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 2}
#
# Лучший алгоритм:
# KNeighborsRegressor(algorithm='auto', leaf_size=15, metric='chebyshev',
#           metric_params=None, n_jobs=-1, n_neighbors=2, p=2,
#           weights='distance')
# MAE = 457.149
# RMSE = 574.900
# Correlation coefficient = 0.091
# 20.489 c

# %%
start_kn_sum = time.time()

kn_sum=KNeighborsRegressor(algorithm='auto', leaf_size=15, metric='chebyshev',
          metric_params=None, n_jobs=-1, n_neighbors=2, p=2,
          weights='distance').fit(X_train_sum,Y_train_sum)

#kn_sum_model=GridTune_sum(kn_sum_params,kn_sum1,5)
kn_sum_predictions=kn_sum.predict(X_test_sum)

scores_kn_sum=predictions_report(Y_test_sum,kn_sum_predictions)
full_time_kn_sum=round(time.time() - start_kn_sum,3)
print(full_time_kn_sum, 'c')
# Out:
# MAE = 445.442
# RMSE = 562.134
# Correlation coefficient = 0.135
# 0.49 c

# %%
output = output.append(pd.Series([str(kn_sum), scores_kn_sum[0],scores_kn_sum[1], 
                                  scores_kn_sum[2][0],full_time_kn_sum,'KNeighborsRegressor по сумме рейтингов'],
                                 index=output.columns ),
                      ignore_index=True)

output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  186.539067  234.559134
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  189.358443  237.420124
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  175.593949  221.353796
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  176.326439  221.767050
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  177.431734  224.595199
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  182.048649  228.384992
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  192.062805  241.580990
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  193.242293  242.404488
# 8   LinearRegression(copy_X=True, fit_intercept=Tr...  171.079101  215.522294
# 9   LinearRegression(copy_X=True, fit_intercept=Tr...  150.700896  192.272077
# 10  LinearRegression(copy_X=True, fit_intercept=Tr...  342.160735  431.049943
# 11  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 12  ExtraTreesRegressor(bootstrap=False, criterion...  148.851787  190.514633
# 13  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 14  KNeighborsRegressor(algorithm='auto', leaf_siz...  445.442198  562.134243
# 15  KNeighborsRegressor(algorithm='auto', leaf_siz...  186.072970  236.294144
# 16  RandomForestRegressor(bootstrap=False, criteri...  352.305849  444.982165
# 17  RandomForestRegressor(bootstrap=True, criterio...  164.729359  206.729387
# 18  KNeighborsRegressor(algorithm='auto', leaf_siz...  445.442198  562.134243
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.486111             0.367
# 1                    0.483303             0.367
# 2                    0.453718             0.164
# 3                    0.461520             0.269
# 4                    0.464714             0.151
# 5                    0.451721             0.142
# 6                    0.467338             0.151
# 7                    0.461618             0.165
# 8                    0.461243             0.370
# 9                    0.574320             0.362
# 10                   0.461242             0.430
# 11                   0.434467          4237.236
# 12                   0.587816          4247.091
# 13                   0.434467          4306.235
# 14                   0.134894             0.500
# 15                   0.333543             0.999
# 16                   0.398389           216.097
# 17                   0.548366            58.591
# 18                   0.134894             0.490
#
#                                           Комментарий
# 0   Обучение на полном набооре -> прогноз рейтинго...
# 1   Обучение на полном набооре -> прогноз рейтинго...
# 2   Обучение только на победах белых -> прогноз ре...
# 3   Обучение только на победах черных -> прогноз р...
# 4   Обучение только на ничьих -> прогноз ретйтинга...
# 5   Обучение только на ничьих -> прогноз ретйтинга...
# 6   Обучение только на проигрышах белых -> прогноз...
# 7   Обучение только на проигрышах черных -> прогно...
# 8                             Обучение на среднем ЭЛО
# 9                      Обучение на разнице в рейтинге
# 10                        Обучение на сумме рейтингов
# 11             ExtraTreesRegressor по сумме рейтингов
# 12          ExtraTreesRegressor на разнице в рейтинге
# 13             ExtraTreesRegressor по сумме рейтингов
# 14             KNeighborsRegressor по сумме рейтингов
# 15          KNeighborsRegressor на разнице в рейтинге
# 16                    RandomForest по сумме рейтингов
# 17                 RandomForest на разнице в рейтинге
# 18             KNeighborsRegressor по сумме рейтингов

# %%
output.to_excel(r'C:\Users\vznam\Downloads\PredictingRatings-master\models\results.xlsx',index=False)

# %%
def GridTune_diff(params,classifiers,folds):
    mae = make_scorer(metrics.mean_absolute_error)
   
    grid = ms.GridSearchCV(classifiers,
                           params,
                           refit=True,  
                           scoring=mae,
                           n_jobs=-1,
                           cv=ms.StratifiedKFold(n_splits=folds))
    
    grid_best_model = grid.fit(X_train_diff2,Y_train_diff2)

    print("Лучшие параметры для MAE:")
    print(grid_best_model.best_params_)
    print('\nЛучший алгоритм:')
    print(grid_best_model.best_estimator_)
    return grid_best_model

# %%
kn_diff_params =[{'n_neighbors':[3,5,9,11,15,20],
            'weights':['uniform','distance'],
            'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
            'metric':['euclidean','manhattan']}]

start_kn_diff = time.time()

kn_diff=KNeighborsRegressor(n_jobs=-1)
kn_diff_model=GridTune_diff(kn_diff_params,kn_diff,5)
kn_diff_predictions=kn_diff_model.predict(X_test_diff2)

scores_kn_diff=predictions_report(Y_test_diff2,kn_diff_predictions)
full_time_kn_diff=round(time.time() - start_kn_diff,3)
print(full_time_kn_diff, 'c')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Лучшие параметры для MAE:
# {'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
#
# Лучший алгоритм:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#           metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
#           weights='uniform')
# MAE = 189.537
# RMSE = 240.934
# Correlation coefficient = 0.252
# 103.205 c

# %%
start_kn_diff = time.time()

kn_diff=KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
          metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
          weights='uniform').fit(X_train_diff,Y_train_diff)

kn_diff_predictions=kn_diff.predict(X_test_diff)

scores_kn_diff=predictions_report(Y_test_diff,kn_diff_predictions)
full_time_kn_diff=round(time.time() - start_kn_diff,3)
print(full_time_kn_diff, 'c')
# Out:
# MAE = 186.073
# RMSE = 236.294
# Correlation coefficient = 0.334
# 0.991 c

# %%
output = output.append(pd.Series([str(kn_diff), scores_kn_diff[0],scores_kn_diff[1], 
                                  scores_kn_diff[2][0],full_time_kn_diff,'KNeighborsRegressor на разнице в рейтинге'],
                                 index=output.columns ),
                      ignore_index=True)

output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  186.539067  234.559134
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  189.358443  237.420124
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  175.593949  221.353796
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  176.326439  221.767050
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  177.431734  224.595199
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  182.048649  228.384992
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  192.062805  241.580990
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  193.242293  242.404488
# 8   LinearRegression(copy_X=True, fit_intercept=Tr...  171.079101  215.522294
# 9   LinearRegression(copy_X=True, fit_intercept=Tr...  150.700896  192.272077
# 10  LinearRegression(copy_X=True, fit_intercept=Tr...  342.160735  431.049943
# 11  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 12  ExtraTreesRegressor(bootstrap=False, criterion...  148.851787  190.514633
# 13  ExtraTreesRegressor(bootstrap=False, criterion...  347.895998  435.982470
# 14  KNeighborsRegressor(algorithm='auto', leaf_siz...  445.442198  562.134243
# 15  KNeighborsRegressor(algorithm='auto', leaf_siz...  186.072970  236.294144
# 16  RandomForestRegressor(bootstrap=False, criteri...  352.305849  444.982165
# 17  RandomForestRegressor(bootstrap=True, criterio...  164.729359  206.729387
# 18  KNeighborsRegressor(algorithm='auto', leaf_siz...  445.442198  562.134243
# 19  KNeighborsRegressor(algorithm='auto', leaf_siz...  186.072970  236.294144
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.486111             0.367
# 1                    0.483303             0.367
# 2                    0.453718             0.164
# 3                    0.461520             0.269
# 4                    0.464714             0.151
# 5                    0.451721             0.142
# 6                    0.467338             0.151
# 7                    0.461618             0.165
# 8                    0.461243             0.370
# 9                    0.574320             0.362
# 10                   0.461242             0.430
# 11                   0.434467          4237.236
# 12                   0.587816          4247.091
# 13                   0.434467          4306.235
# 14                   0.134894             0.500
# 15                   0.333543             0.999
# 16                   0.398389           216.097
# 17                   0.548366            58.591
# 18                   0.134894             0.490
# 19                   0.333543             0.991
#
#                                           Комментарий
# 0   Обучение на полном набооре -> прогноз рейтинго...
# 1   Обучение на полном набооре -> прогноз рейтинго...
# 2   Обучение только на победах белых -> прогноз ре...
# 3   Обучение только на победах черных -> прогноз р...
# 4   Обучение только на ничьих -> прогноз ретйтинга...
# 5   Обучение только на ничьих -> прогноз ретйтинга...
# 6   Обучение только на проигрышах белых -> прогноз...
# 7   Обучение только на проигрышах черных -> прогно...
# 8                             Обучение на среднем ЭЛО
# 9                      Обучение на разнице в рейтинге
# 10                        Обучение на сумме рейтингов
# 11             ExtraTreesRegressor по сумме рейтингов
# 12          ExtraTreesRegressor на разнице в рейтинге
# 13             ExtraTreesRegressor по сумме рейтингов
# 14             KNeighborsRegressor по сумме рейтингов
# 15          KNeighborsRegressor на разнице в рейтинге
# 16                    RandomForest по сумме рейтингов
# 17                 RandomForest на разнице в рейтинге
# 18             KNeighborsRegressor по сумме рейтингов
# 19          KNeighborsRegressor на разнице в рейтинге

# %%
#output.to_excel(r'C:\Users\Asus\PredictingRatings\models\results.xlsx',index=False)
output.to_excel(r'C:\Users\vznam\Downloads\PredictingRatings-master\models\results.xlsx',index=False)

# %%
white_elos = (kn_sum_predictions + kn_diff_predictions)/2
black_elos = (kn_sum_predictions-kn_diff_predictions)/2
pred_elos=list(zip(white_elos,black_elos))
pred_elos[:5],elos[:5]
# Out:
# ([(2310.363753932741, 2304.697087266074),
#   (2050.6062081969058, 2212.939541530239),
#   (2240.132354311486, 2395.465687644819),
#   (2338.9802099867675, 2352.9802099867675),
#   (2224.1644248242956, 2364.8310914909625)],
#     WhiteElo  BlackElo  MeanElos  DiffElos  SumElos
#  0      2354      2411      2382       -57     4765
#  1      1915      1999      1957       -84     3914
#  2      2446      2191      2318       255     4637
#  3      2168      2075      2121        93     4243
#  4      2437      2254      2345       183     4691)

# %%
def find_mean_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=elos.iloc[ind,0]-val[0]
        er+=elos.iloc[ind,1]-val[1]
        count+=2
    return round(er/count,5)

def find_abs_error(pred,elos):
    er=0
    for ind, val in enumerate(pred):
        er+=elos.iloc[ind,0]-val[0]
        er+=elos.iloc[ind,1]-val[1]
    return round(er,5)

# %%
find_abs_error(pred_elos,elos),find_mean_error(pred_elos,elos)
# Out:
# (-47278.912, -3.24852)
