# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.ensemble import AdaBoostRegressor
from sklearn import model_selection as ms
from scipy.stats import pearsonr
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.feature_selection import VarianceThreshold

rand_st=4

# %%
output=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx')
errors=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx')

# %%
elos_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos1.csv')
elos_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos2.csv')
elos_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos3.csv')
elos_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos4.csv')
features_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features1.csv')
features_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features3.csv')
features_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features2.csv')
features_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features4.csv')

# %%
X_train_mean_1, X_test_mean_1, Y_train_mean_1, Y_test_mean_1 =ms.train_test_split(features_1, elos_1['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_1, X_test_diff_1, Y_train_diff_1, Y_test_diff_1 =ms.train_test_split(features_1, elos_1['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_2, X_test_mean_2, Y_train_mean_2, Y_test_mean_2 =ms.train_test_split(features_2, elos_2['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_2, X_test_diff_2, Y_train_diff_2, Y_test_diff_2 =ms.train_test_split(features_2, elos_2['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_3, X_test_mean_3, Y_train_mean_3, Y_test_mean_3 =ms.train_test_split(features_3, elos_3['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_3, X_test_diff_3, Y_train_diff_3, Y_test_diff_3 =ms.train_test_split(features_3, elos_3['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_4, X_test_mean_4, Y_train_mean_4, Y_test_mean_4 =ms.train_test_split(features_4, elos_4['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_4, X_test_diff_4, Y_train_diff_4, Y_test_diff_4 =ms.train_test_split(features_4, elos_4['DiffElos'], test_size = 0.3,random_state=rand_st)

# %%
model_mean=AdaBoostRegressor(base_estimator=None, learning_rate=2, loss='square',n_estimators=500, random_state=4)
model_diff=AdaBoostRegressor(base_estimator=None, learning_rate=2, loss='square',n_estimators=50, random_state=4)

# %%
def find_mean_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
        count+=2
    return round(er/count,3)

def find_abs_error(pred,elos):
    er=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
    return round(er,3)

def find_root_mean_squared_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=(elos.iloc[ind,0]-val[0])**2
        er+=(elos.iloc[ind,1]-val[1])**2
        count+=2
    return round((er/count)**0.5,3)

# %%
def predictions_report(pred_target,predictions):
    mae_report=mae(pred_target,predictions)
    print ('MAE = {:.3f}'.format(mae_report))
    
    rmse_report = (mse(pred_target, predictions))**0.5
    print ('RMSE = {:.3f}'.format(rmse_report))
    
    corr_coef = pearsonr(pred_target,predictions)
    print("Correlation coefficient = {:.3f}".format(corr_coef[0]))
    
    return (mae_report,rmse_report,corr_coef)

# %% [markdown]
# ### Подбор модели для 1 кластера

# %%
start1 = time.time()

ada1=model_mean.fit(X_train_mean_1,Y_train_mean_1)
ada_pred1=ada1.predict(X_test_mean_1)
scores1=predictions_report(Y_test_mean_1,ada_pred1)
full_time1=round(time.time() - start1,3)
print(full_time1, 'c')
# Out:
# MAE = 179.647
# RMSE = 226.248
# Correlation coefficient = 0.378
# 92.909 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores1[0],scores1[1], 
                                 scores1[2][0],full_time1,'Обучение на среднем ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру

# %%
start2 = time.time()

ada2=model_diff.fit(X_train_diff_1,Y_train_diff_1)
ada_pred2=ada2.predict(X_test_mean_1)
scores2=predictions_report(Y_test_diff_1,ada_pred2)
full_time2=round(time.time() - start2,3)
print(full_time2, 'c')
# Out:
# MAE = 156.775
# RMSE = 200.335
# Correlation coefficient = 0.535
# 9.809 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores2[0],scores2[1], 
                                 scores2[2][0],full_time2,'Обучение на разнице ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_1 = ada_pred1 + ada_pred2/2
black_elos_1 = ada_pred1-ada_pred2/2
pred_elos1=list(zip(white_elos_1,black_elos_1))
print(len(pred_elos1))
pred_elos1[:5]
# Out:
# 6577
# [(2191.3867414513666, 2152.8613040354853),
#  (2240.408567936464, 2280.279910015172),
#  (1798.9014980690035, 2104.068605652778),
#  (2193.4965609643227, 2371.6387386611455),
#  (2204.454785126828, 2317.685062312329)]

# %%
find_abs_error(pred_elos1,elos_1),find_mean_error(pred_elos1,elos_1),find_root_mean_squared_error(pred_elos1,elos_1)
# Out:
# (3217282.803, 244.586, 306.169)

# %%
inner_mae_1=find_mean_error(pred_elos1,elos_1)

# %%
errors =errors.append(pd.Series(['1 кластер','AdaBoost',
                  find_abs_error(pred_elos1,elos_1),
                  find_mean_error(pred_elos1,elos_1),
                   find_root_mean_squared_error(pred_elos1,elos_1) ],
                                   index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06  189.45700  237.56700
# 1      2 кластер  LinearRegression       2.481410e+05  180.86100  228.08700
# 2      3 кластер  LinearRegression       5.772583e+04  126.03900  162.09500
# 3      4 кластер  LinearRegression       5.350485e+05  188.53000  237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06  171.22175  216.26225
# 5      1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 6      2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 7      3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 8      4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
# 10     1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900

# %%
errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)

# %% [markdown]
# ### Подбор модели для 2 кластера

# %%
start3 = time.time()

ada3=model_mean.fit(X_train_mean_2,Y_train_mean_2)
ada_pred3=ada3.predict(X_test_mean_2)
scores3=predictions_report(Y_test_mean_2,ada_pred3)
full_time3=round(time.time() - start3,3)
print(full_time3, 'c')
# Out:
# MAE = 400.374
# RMSE = 460.450
# Correlation coefficient = 0.158
# 1.017 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores3[0],scores3[1], 
                                 scores3[2][0],full_time3,'Обучение на среднем ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру

# %%
start4 = time.time()

ada4=model_diff.fit(X_train_diff_2,Y_train_diff_2)
ada_pred4=ada4.predict(X_test_mean_2)
scores4=predictions_report(Y_test_diff_2,ada_pred4)
full_time4=round(time.time() - start4,3)
print(full_time4, 'c')
# Out:
# MAE = 245.541
# RMSE = 300.516
# Correlation coefficient = 0.429
# 0.209 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores4[0],scores4[1], 
                                 scores4[2][0],full_time4,'Обучение на разнице ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 19  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
# 19                   0.429194             0.209
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_2 = ada_pred3 + ada_pred3/2
black_elos_2 = ada_pred3-ada_pred4/2
pred_elos2=list(zip(white_elos_2,black_elos_2))
print(len(pred_elos2))
pred_elos2[:5]
# Out:
# 206
# [(2637.715909090909, 1630.9772727272727),
#  (3943.5, 2499.5),
#  (3882.0, 2455.0),
#  (3637.5, 2274.102564102564),
#  (2767.5, 1679.555706521739)]

# %%
find_abs_error(pred_elos2,elos_2),find_mean_error(pred_elos2,elos_2),find_root_mean_squared_error(pred_elos2,elos_2)
# Out:
# (281032.163, 682.117, 886.276)

# %%
inner_mae_2=find_mean_error(pred_elos2,elos_2)

# %%
errors =errors.append(pd.Series(['2 кластер','AdaBoost',
                        find_abs_error(pred_elos2,elos_2),
                        find_mean_error(pred_elos2,elos_2),
                        find_root_mean_squared_error(pred_elos2,elos_2)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06  189.45700  237.56700
# 1      2 кластер  LinearRegression       2.481410e+05  180.86100  228.08700
# 2      3 кластер  LinearRegression       5.772583e+04  126.03900  162.09500
# 3      4 кластер  LinearRegression       5.350485e+05  188.53000  237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06  171.22175  216.26225
# 5      1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 6      2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 7      3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 8      4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
# 10     1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 11     2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600

# %% [markdown]
# ### Подбор модели для 3 кластера

# %%
start5 = time.time()

ada5=model_mean.fit(X_train_mean_3,Y_train_mean_3)
ada_pred5=ada5.predict(X_test_mean_3)
scores5=predictions_report(Y_test_mean_3,ada_pred5)
full_time5=round(time.time() - start5,3)
print(full_time5, 'c')
# Out:
# MAE = 353.560
# RMSE = 430.233
# Correlation coefficient = 0.282
# 0.633 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores5[0],scores5[1], 
                                 scores5[2][0],full_time5,'Обучение на среднем ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 19  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 20  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
# 19                   0.429194             0.209
# 20                   0.282200             0.633
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру

# %%
start6 = time.time()

ada6=model_diff.fit(X_train_diff_3,Y_train_diff_3)
ada_pred6=ada6.predict(X_test_mean_3)
scores6=predictions_report(Y_test_diff_3,ada_pred6)
full_time6=round(time.time() - start6,3)
print(full_time6, 'c')
# Out:
# MAE = 190.006
# RMSE = 250.802
# Correlation coefficient = 0.487
# 0.087 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores6[0],scores6[1], 
                                 scores6[2][0],full_time6,'Обучение на разнице ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 19  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 20  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 21  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
# 19                   0.429194             0.209
# 20                   0.282200             0.633
# 21                   0.487295             0.087
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_3 = ada_pred5 + ada_pred6/2
black_elos_3 = ada_pred5-ada_pred6/2
pred_elos3=list(zip(white_elos_3,black_elos_3))
print(len(pred_elos3))
pred_elos3[:5]
# Out:
# 69
# [(2278.6659090909093, 2521.9159090909093),
#  (1574.304347826087, 1769.695652173913),
#  (1583.0, 1455.0),
#  (1690.96875, 1653.03125),
#  (1737.3333333333333, 1612.6666666666667)]

# %%
find_abs_error(pred_elos3,elos_3),find_mean_error(pred_elos3,elos_3),find_root_mean_squared_error(pred_elos3,elos_3)
# Out:
# (53461.011, 387.399, 479.349)

# %%
inner_mae_3=find_mean_error(pred_elos3,elos_3)

# %%
errors =errors.append(pd.Series(['3 кластер','AdaBoost',
                                 find_abs_error(pred_elos3,elos_3),
                                 find_mean_error(pred_elos3,elos_3),
                                 find_root_mean_squared_error(pred_elos3,elos_3)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06  189.45700  237.56700
# 1      2 кластер  LinearRegression       2.481410e+05  180.86100  228.08700
# 2      3 кластер  LinearRegression       5.772583e+04  126.03900  162.09500
# 3      4 кластер  LinearRegression       5.350485e+05  188.53000  237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06  171.22175  216.26225
# 5      1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 6      2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 7      3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 8      4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
# 10     1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 11     2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 12     3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900

# %% [markdown]
# ### Подбор модели для 4 кластера

# %%
start7 = time.time()

ada7=model_mean.fit(X_train_mean_4,Y_train_mean_4)
ada_pred7=ada7.predict(X_test_mean_4)
scores7=predictions_report(Y_test_mean_4,ada_pred7)
full_time7=round(time.time() - start7,3)
print(full_time7, 'c')
# Out:
# MAE = 302.541
# RMSE = 365.562
# Correlation coefficient = 0.222
# 3.257 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores7[0],scores7[1], 
                                 scores7[2][0],full_time7,'Обучение на среднем ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 19  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 20  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 21  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 22  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
# 19                   0.429194             0.209
# 20                   0.282200             0.633
# 21                   0.487295             0.087
# 22                   0.222091             3.257
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру

# %%
start8 = time.time()

ada8=model_diff.fit(X_train_diff_4,Y_train_diff_4)
ada_pred8=ada8.predict(X_test_mean_4)
scores8=predictions_report(Y_test_diff_4,ada_pred8)
full_time8=round(time.time() - start8,3)
print(full_time8, 'c')
# Out:
# MAE = 203.617
# RMSE = 251.328
# Correlation coefficient = 0.405
# 0.492 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores8[0],scores8[1], 
                                 scores8[2][0],full_time8,'Обучение на разнице ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  172.744949  217.273742
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  150.440190  192.130211
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...  166.629660  207.827945
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  146.568185  187.970319
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...  117.564897  150.552498
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   95.694204  120.219588
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...  172.852117  217.358897
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  149.357283  190.437205
# 8   AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 9   AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 10  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 11  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 12  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 13  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 14  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 15  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
# 16  AdaBoostRegressor(base_estimator=None, learnin...  179.646548  226.247606
# 17  AdaBoostRegressor(base_estimator=None, learnin...  156.774713  200.334686
# 18  AdaBoostRegressor(base_estimator=None, learnin...  400.373757  460.449596
# 19  AdaBoostRegressor(base_estimator=None, learnin...  245.541314  300.516270
# 20  AdaBoostRegressor(base_estimator=None, learnin...  353.559556  430.232703
# 21  AdaBoostRegressor(base_estimator=None, learnin...  190.005606  250.801859
# 22  AdaBoostRegressor(base_estimator=None, learnin...  302.540631  365.562050
# 23  AdaBoostRegressor(base_estimator=None, learnin...  203.616830  251.328246
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.428199             1.174
# 1                    0.572216             0.113
# 2                    0.569104             0.107
# 3                    0.641182             0.008
# 4                    0.831412             0.009
# 5                    0.873861             0.008
# 6                    0.509381             0.013
# 7                    0.594318             0.012
# 8                    0.377671            92.545
# 9                    0.535215            10.463
# 10                   0.158157             1.081
# 11                   0.429194             0.257
# 12                   0.282200             0.781
# 13                   0.487295             0.157
# 14                   0.222091             4.528
# 15                   0.405406             0.613
# 16                   0.377671            92.909
# 17                   0.535215             9.809
# 18                   0.158157             1.017
# 19                   0.429194             0.209
# 20                   0.282200             0.633
# 21                   0.487295             0.087
# 22                   0.222091             3.257
# 23                   0.405406             0.492
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру

# %%
white_elos_4 = ada_pred7 + ada_pred8/2
black_elos_4 = ada_pred7-ada_pred8/2
pred_elos4=list(zip(white_elos_4,black_elos_4))
print(len(pred_elos4))
pred_elos4[:5]
# Out:
# 426
# [(2177.190135135135, 2249.080135135135),
#  (2554.435824742268, 2440.2858247422682),
#  (1954.8456284153006, 1703.1543715846994),
#  (1972.9901234567901, 2236.99012345679),
#  (2536.326286764706, 2319.673713235294)]

# %%
find_abs_error(pred_elos4,elos_4),find_mean_error(pred_elos4,elos_4),find_root_mean_squared_error(pred_elos4,elos_4)
# Out:
# (310884.301, 364.888, 454.873)

# %%
inner_mae_4=find_mean_error(pred_elos4,elos_4)

# %%
errors =errors.append(pd.Series(['4 кластер','AdaBoost',find_abs_error(pred_elos4,elos_4),
                                 find_mean_error(pred_elos4,elos_4),
                                 find_root_mean_squared_error(pred_elos4,elos_4)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06  189.45700  237.56700
# 1      2 кластер  LinearRegression       2.481410e+05  180.86100  228.08700
# 2      3 кластер  LinearRegression       5.772583e+04  126.03900  162.09500
# 3      4 кластер  LinearRegression       5.350485e+05  188.53000  237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06  171.22175  216.26225
# 5      1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 6      2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 7      3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 8      4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
# 10     1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 11     2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 12     3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 13     4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300

# %%
ada_mae=(inner_mae_4+inner_mae_3+inner_mae_2+inner_mae_1)/4
ada_mae
# Out:
# 419.7475

# %%
ada_abs=(find_abs_error(pred_elos1,elos_1)+
        find_abs_error(pred_elos2,elos_2)+
        find_abs_error(pred_elos3,elos_3)+
        find_abs_error(pred_elos4,elos_4))/4
ada_abs
# Out:
# 965665.0695

# %%
ada_rmse=(find_root_mean_squared_error(pred_elos1,elos_1)+
         find_root_mean_squared_error(pred_elos2,elos_2)+
         find_root_mean_squared_error(pred_elos3,elos_3)+
         find_root_mean_squared_error(pred_elos4,elos_4))/4
ada_rmse
# Out:
# 531.66675

# %%
errors = errors.append(pd.Series(['Общая ошибка','AdaBoost',
                  ada_abs,
                  ada_mae,
                 ada_rmse],index=errors.columns) ,ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06  189.45700  237.56700
# 1      2 кластер  LinearRegression       2.481410e+05  180.86100  228.08700
# 2      3 кластер  LinearRegression       5.772583e+04  126.03900  162.09500
# 3      4 кластер  LinearRegression       5.350485e+05  188.53000  237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06  171.22175  216.26225
# 5      1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 6      2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 7      3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 8      4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
# 10     1 кластер          AdaBoost       3.217283e+06  244.58600  306.16900
# 11     2 кластер          AdaBoost       2.810322e+05  682.11700  886.27600
# 12     3 кластер          AdaBoost       5.346101e+04  387.39900  479.34900
# 13     4 кластер          AdaBoost       3.108843e+05  364.88800  454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05  419.74750  531.66675
