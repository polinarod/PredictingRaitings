# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.neighbors import KNeighborsRegressor
from sklearn import model_selection as ms
from scipy.stats import pearsonr
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.feature_selection import VarianceThreshold

rand_st=4

# %%
output=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx')
errors=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx')

# %%
elos_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos1.csv')
elos_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos2.csv')
elos_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos3.csv')
elos_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos4.csv')
features_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features1.csv')
features_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features3.csv')
features_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features2.csv')
features_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features4.csv')

# %%
X_train_mean_1, X_test_mean_1, Y_train_mean_1, Y_test_mean_1 =ms.train_test_split(features_1, elos_1['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_1, X_test_diff_1, Y_train_diff_1, Y_test_diff_1 =ms.train_test_split(features_1, elos_1['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_2, X_test_mean_2, Y_train_mean_2, Y_test_mean_2 =ms.train_test_split(features_2, elos_2['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_2, X_test_diff_2, Y_train_diff_2, Y_test_diff_2 =ms.train_test_split(features_2, elos_2['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_3, X_test_mean_3, Y_train_mean_3, Y_test_mean_3 =ms.train_test_split(features_3, elos_3['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_3, X_test_diff_3, Y_train_diff_3, Y_test_diff_3 =ms.train_test_split(features_3, elos_3['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_4, X_test_mean_4, Y_train_mean_4, Y_test_mean_4 =ms.train_test_split(features_4, elos_4['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_4, X_test_diff_4, Y_train_diff_4, Y_test_diff_4 =ms.train_test_split(features_4, elos_4['DiffElos'], test_size = 0.3,random_state=rand_st)

# %%
model_mean=KNeighborsRegressor(algorithm='auto', leaf_size=15, metric='chebyshev',
          metric_params=None, n_jobs=-1, n_neighbors=2, p=2,
          weights='distance')

model_diff=KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
          metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
          weights='uniform')

# %%
def find_mean_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
        count+=2
    return round(er/count,3)

def find_abs_error(pred,elos):
    er=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
    return round(er,3)

def find_root_mean_squared_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=(elos.iloc[ind,0]-val[0])**2
        er+=(elos.iloc[ind,1]-val[1])**2
        count+=2
    return round((er/count)**0.5,3)

# %%
def predictions_report(pred_target,predictions):
    mae_report=mae(pred_target,predictions)
    print ('MAE = {:.3f}'.format(mae_report))
    
    rmse_report = (mse(pred_target, predictions))**0.5
    print ('RMSE = {:.3f}'.format(rmse_report))
    
    corr_coef = pearsonr(pred_target,predictions)
    print("Correlation coefficient = {:.3f}".format(corr_coef[0]))
    
    return (mae_report,rmse_report,corr_coef)

# %% [markdown]
# ### Подбор модели для 1 кластера

# %%
start1 = time.time()

knr1=model_mean.fit(X_train_mean_1,Y_train_mean_1)
knr_pred1=knr1.predict(X_test_mean_1)
scores1=predictions_report(Y_test_mean_1,knr_pred1)
full_time1=round(time.time() - start1,3)
print(full_time1, 'c')
# Out:
# MAE = 219.590
# RMSE = 277.392
# Correlation coefficient = 0.145
# 0.768 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores1[0],scores1[1], 
                                 scores1[2][0],full_time1,'Обучение на среднем ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру

# %%
start2 = time.time()

knr2=model_diff.fit(X_train_diff_1,Y_train_diff_1)
knr_pred2=knr2.predict(X_test_mean_1)
scores2=predictions_report(Y_test_diff_1,knr_pred2)
full_time2=round(time.time() - start2,3)
print(full_time2, 'c')
# Out:
# MAE = 177.750
# RMSE = 225.615
# Correlation coefficient = 0.396
# 0.925 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores2[0],scores2[1], 
                                 scores2[2][0],full_time2,'Обучение на разнице ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_1 = knr_pred1 + knr_pred2/2
black_elos_1 = knr_pred1-knr_pred2/2
pred_elos1=list(zip(white_elos_1,black_elos_1))
print(len(pred_elos1))
pred_elos1[:5]
# Out:
# 6577
# [(2115.8571428571427, 2210.5238095238096),
#  (2653.4790667580114, 2565.1457334246784),
#  (1797.5702165841915, 1672.5702165841915),
#  (2078.781345565749, 2152.4480122324157),
#  (2330.2371809735814, 2348.9038476402484)]

# %%
find_abs_error(pred_elos1,elos_1),find_mean_error(pred_elos1,elos_1),find_root_mean_squared_error(pred_elos1,elos_1)
# Out:
# (3453794.854, 262.566, 329.658)

# %%
inner_mae_1=find_mean_error(pred_elos1,elos_1)

# %%
errors =errors.append(pd.Series(['1 кластер','K-Neighbors',
                  find_abs_error(pred_elos1,elos_1),
                  find_mean_error(pred_elos1,elos_1),
                   find_root_mean_squared_error(pred_elos1,elos_1) ],
                                   index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE         RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06   189.45700    237.56700
# 1      2 кластер  LinearRegression       2.481410e+05   180.86100    228.08700
# 2      3 кластер  LinearRegression       5.772583e+04   126.03900    162.09500
# 3      4 кластер  LinearRegression       5.350485e+05   188.53000    237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06   171.22175    216.26225
# 5      1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 6      2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 7      3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 8      4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 10     1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 11     2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 12     3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 13     4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 15     1 кластер        ElasticNet       3.676407e+06   279.49000    360.94600
# 16     2 кластер        ElasticNet       2.794689e+05   678.32300    865.25800
# 17     3 кластер        ElasticNet       7.453663e+05  5401.20500  45543.50900
# 18     4 кластер        ElasticNet       3.233976e+05   379.57500   1427.39000
# 19  Общая ошибка        ElasticNet       1.256160e+06  1684.64825  12049.27575
# 20     1 кластер       K-Neighbors       3.453795e+06   262.56600    329.65800

# %%
errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)

# %% [markdown]
# ### Подбор модели для 2 кластера

# %%
start3 = time.time()

knr3=model_mean.fit(X_train_mean_2,Y_train_mean_2)
knr_pred3=knr3.predict(X_test_mean_2)
scores3=predictions_report(Y_test_mean_2,knr_pred3)
full_time3=round(time.time() - start3,3)
print(full_time3, 'c')
# Out:
# MAE = 236.428
# RMSE = 299.658
# Correlation coefficient = 0.113
# 0.12 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores3[0],scores3[1], 
                                 scores3[2][0],full_time3,'Обучение на среднем ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру

# %%
start4 = time.time()

knr4=model_diff.fit(X_train_diff_2,Y_train_diff_2)
knr_pred4=knr4.predict(X_test_mean_2)
scores4=predictions_report(Y_test_diff_2,knr_pred4)
full_time4=round(time.time() - start4,3)
print(full_time4, 'c')
# Out:
# MAE = 197.147
# RMSE = 251.540
# Correlation coefficient = 0.287
# 0.118 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores4[0],scores4[1], 
                                 scores4[2][0],full_time4,'Обучение на разнице ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...    197.147249
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
# 35    251.539893                   0.286941             0.118
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру
# 35     Обучение на разнице ЭЛО по 2 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_2 = knr_pred3 + knr_pred3/2
black_elos_2 = knr_pred3-knr_pred4/2
pred_elos2=list(zip(white_elos_2,black_elos_2))
print(len(pred_elos2))
pred_elos2[:5]
# Out:
# 206
# [(2842.0621961199636, 1885.7081307466424),
#  (3511.240091115544, 2378.4933940770293),
#  (3579.1933748896736, 2283.462249926449),
#  (3463.0654758136034, 2162.0436505424022),
#  (3443.188649386888, 2230.4590995912586)]

# %%
find_abs_error(pred_elos2,elos_2),find_mean_error(pred_elos2,elos_2),find_root_mean_squared_error(pred_elos2,elos_2)
# Out:
# (277427.374, 673.367, 841.525)

# %%
inner_mae_2=find_mean_error(pred_elos2,elos_2)

# %%
errors =errors.append(pd.Series(['2 кластер','K-Neighbors',
                        find_abs_error(pred_elos2,elos_2),
                        find_mean_error(pred_elos2,elos_2),
                        find_root_mean_squared_error(pred_elos2,elos_2)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE         RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06   189.45700    237.56700
# 1      2 кластер  LinearRegression       2.481410e+05   180.86100    228.08700
# 2      3 кластер  LinearRegression       5.772583e+04   126.03900    162.09500
# 3      4 кластер  LinearRegression       5.350485e+05   188.53000    237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06   171.22175    216.26225
# 5      1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 6      2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 7      3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 8      4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 10     1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 11     2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 12     3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 13     4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 15     1 кластер        ElasticNet       3.676407e+06   279.49000    360.94600
# 16     2 кластер        ElasticNet       2.794689e+05   678.32300    865.25800
# 17     3 кластер        ElasticNet       7.453663e+05  5401.20500  45543.50900
# 18     4 кластер        ElasticNet       3.233976e+05   379.57500   1427.39000
# 19  Общая ошибка        ElasticNet       1.256160e+06  1684.64825  12049.27575
# 20     1 кластер       K-Neighbors       3.453795e+06   262.56600    329.65800
# 21     2 кластер       K-Neighbors       2.774274e+05   673.36700    841.52500

# %% [markdown]
# ### Подбор модели для 3 кластера

# %%
start5 = time.time()

knr5=model_mean.fit(X_train_mean_3,Y_train_mean_3)
knr_pred5=knr5.predict(X_test_mean_3)
scores5=predictions_report(Y_test_mean_3,knr_pred5)
full_time5=round(time.time() - start5,3)
print(full_time5, 'c')
# Out:
# MAE = 249.055
# RMSE = 310.406
# Correlation coefficient = 0.073
# 0.113 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores5[0],scores5[1], 
                                 scores5[2][0],full_time5,'Обучение на среднем ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...    197.147249
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...    249.055392
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
# 35    251.539893                   0.286941             0.118
# 36    310.405843                   0.072860             0.113
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру
# 35     Обучение на разнице ЭЛО по 2 кластеру
# 36     Обучение на среднем ЭЛО по 3 кластеру

# %%
start6 = time.time()

knr6=model_diff.fit(X_train_diff_3,Y_train_diff_3)
knr_pred6=knr6.predict(X_test_mean_3)
scores6=predictions_report(Y_test_diff_3,knr_pred6)
full_time6=round(time.time() - start6,3)
print(full_time6, 'c')
# Out:
# MAE = 222.990
# RMSE = 274.804
# Correlation coefficient = 0.124
# 0.112 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores6[0],scores6[1], 
                                 scores6[2][0],full_time6,'Обучение на разнице ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...    197.147249
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...    249.055392
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...    222.990338
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
# 35    251.539893                   0.286941             0.118
# 36    310.405843                   0.072860             0.113
# 37    274.804322                   0.123544             0.112
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру
# 35     Обучение на разнице ЭЛО по 2 кластеру
# 36     Обучение на среднем ЭЛО по 3 кластеру
# 37     Обучение на разнице ЭЛО по 3 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_3 = knr_pred5 + knr_pred6/2
black_elos_3 = knr_pred5-knr_pred6/2
pred_elos3=list(zip(white_elos_3,black_elos_3))
print(len(pred_elos3))
pred_elos3[:5]
# Out:
# 69
# [(1759.914231692564, 2141.5808983592306),
#  (2288.1087880461155, 2457.7754547127824),
#  (2224.415574714826, 2123.082241381493),
#  (2178.393580584525, 2107.393580584525),
#  (2228.3423257765185, 2320.0089924431854)]

# %%
find_abs_error(pred_elos3,elos_3),find_mean_error(pred_elos3,elos_3),find_root_mean_squared_error(pred_elos3,elos_3)
# Out:
# (38870.682, 281.672, 348.714)

# %%
inner_mae_3=find_mean_error(pred_elos3,elos_3)

# %%
errors =errors.append(pd.Series(['3 кластер','K-Neighbors',
                                 find_abs_error(pred_elos3,elos_3),
                                 find_mean_error(pred_elos3,elos_3),
                                 find_root_mean_squared_error(pred_elos3,elos_3)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE         RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06   189.45700    237.56700
# 1      2 кластер  LinearRegression       2.481410e+05   180.86100    228.08700
# 2      3 кластер  LinearRegression       5.772583e+04   126.03900    162.09500
# 3      4 кластер  LinearRegression       5.350485e+05   188.53000    237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06   171.22175    216.26225
# 5      1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 6      2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 7      3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 8      4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 10     1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 11     2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 12     3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 13     4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 15     1 кластер        ElasticNet       3.676407e+06   279.49000    360.94600
# 16     2 кластер        ElasticNet       2.794689e+05   678.32300    865.25800
# 17     3 кластер        ElasticNet       7.453663e+05  5401.20500  45543.50900
# 18     4 кластер        ElasticNet       3.233976e+05   379.57500   1427.39000
# 19  Общая ошибка        ElasticNet       1.256160e+06  1684.64825  12049.27575
# 20     1 кластер       K-Neighbors       3.453795e+06   262.56600    329.65800
# 21     2 кластер       K-Neighbors       2.774274e+05   673.36700    841.52500
# 22     3 кластер       K-Neighbors       3.887068e+04   281.67200    348.71400

# %% [markdown]
# ### Подбор модели для 4 кластера

# %%
start7 = time.time()

knr7=model_mean.fit(X_train_mean_4,Y_train_mean_4)
knr_pred7=knr7.predict(X_test_mean_4)
scores7=predictions_report(Y_test_mean_4,knr_pred7)
full_time7=round(time.time() - start7,3)
print(full_time7, 'c')
# Out:
# MAE = 237.175
# RMSE = 296.745
# Correlation coefficient = 0.059
# 0.118 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores7[0],scores7[1], 
                                 scores7[2][0],full_time7,'Обучение на среднем ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...    197.147249
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...    249.055392
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...    222.990338
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...    237.175003
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
# 35    251.539893                   0.286941             0.118
# 36    310.405843                   0.072860             0.113
# 37    274.804322                   0.123544             0.112
# 38    296.745116                   0.058677             0.118
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру
# 35     Обучение на разнице ЭЛО по 2 кластеру
# 36     Обучение на среднем ЭЛО по 3 кластеру
# 37     Обучение на разнице ЭЛО по 3 кластеру
# 38     Обучение на среднем ЭЛО по 4 кластеру

# %%
start8 = time.time()

knr8=model_diff.fit(X_train_diff_4,Y_train_diff_4)
knr_pred8=knr8.predict(X_test_mean_4)
scores8=predictions_report(Y_test_diff_4,knr_pred8)
full_time8=round(time.time() - start8,3)
print(full_time8, 'c')
# Out:
# MAE = 198.131
# RMSE = 245.053
# Correlation coefficient = 0.289
# 0.117 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores8[0],scores8[1], 
                                 scores8[2][0],full_time8,'Обучение на разнице ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель           MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...    172.744949
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    150.440190
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    166.629660
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...    146.568185
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    117.564897
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...     95.694204
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    172.852117
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...    149.357283
# 8   AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 9   AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 10  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 11  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 12  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 13  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 14  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 15  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 16  AdaBoostRegressor(base_estimator=None, learnin...    179.646548
# 17  AdaBoostRegressor(base_estimator=None, learnin...    156.774713
# 18  AdaBoostRegressor(base_estimator=None, learnin...    400.373757
# 19  AdaBoostRegressor(base_estimator=None, learnin...    245.541314
# 20  AdaBoostRegressor(base_estimator=None, learnin...    353.559556
# 21  AdaBoostRegressor(base_estimator=None, learnin...    190.005606
# 22  AdaBoostRegressor(base_estimator=None, learnin...    302.540631
# 23  AdaBoostRegressor(base_estimator=None, learnin...    203.616830
# 24  ElasticNet(alpha=1, copy_X=True, fit_intercept...    240.278801
# 25  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    149.852092
# 26  ElasticNet(alpha=1, copy_X=True, fit_intercept...    238.059634
# 27  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    197.253490
# 28  ElasticNet(alpha=1, copy_X=True, fit_intercept...   2558.474736
# 29  ElasticNet(alpha=0.5, copy_X=True, fit_interce...  10415.503182
# 30  ElasticNet(alpha=1, copy_X=True, fit_intercept...    297.102458
# 31  ElasticNet(alpha=0.5, copy_X=True, fit_interce...    196.343819
# 32  KNeighborsRegressor(algorithm='auto', leaf_siz...    219.590186
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...    177.749683
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...    236.428272
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...    197.147249
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...    249.055392
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...    222.990338
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...    237.175003
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...    198.131455
#
#             RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0     217.273742                   0.428199             1.174
# 1     192.130211                   0.572216             0.113
# 2     207.827945                   0.569104             0.107
# 3     187.970319                   0.641182             0.008
# 4     150.552498                   0.831412             0.009
# 5     120.219588                   0.873861             0.008
# 6     217.358897                   0.509381             0.013
# 7     190.437205                   0.594318             0.012
# 8     226.247606                   0.377671            92.545
# 9     200.334686                   0.535215            10.463
# 10    460.449596                   0.158157             1.081
# 11    300.516270                   0.429194             0.257
# 12    430.232703                   0.282200             0.781
# 13    250.801859                   0.487295             0.157
# 14    365.562050                   0.222091             4.528
# 15    251.328246                   0.405406             0.613
# 16    226.247606                   0.377671            92.909
# 17    200.334686                   0.535215             9.809
# 18    460.449596                   0.158157             1.017
# 19    300.516270                   0.429194             0.209
# 20    430.232703                   0.282200             0.633
# 21    250.801859                   0.487295             0.087
# 22    365.562050                   0.222091             3.257
# 23    251.328246                   0.405406             0.492
# 24    313.460387                   0.147357             2.910
# 25    191.559340                   0.561116             1.486
# 26    308.318305                   0.274455             0.063
# 27    278.140830                   0.289340             0.055
# 28  18692.100405                  -0.070448             0.024
# 29  83063.928158                  -0.156097             0.023
# 30   1358.798794                   0.116872             0.091
# 31    662.445783                   0.068187             0.102
# 32    277.391623                   0.145349             0.768
# 33    225.614671                   0.395950             0.925
# 34    299.657866                   0.112944             0.120
# 35    251.539893                   0.286941             0.118
# 36    310.405843                   0.072860             0.113
# 37    274.804322                   0.123544             0.112
# 38    296.745116                   0.058677             0.118
# 39    245.052690                   0.288771             0.117
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по 1 кластеру
# 17     Обучение на разнице ЭЛО по 1 кластеру
# 18     Обучение на среднем ЭЛО по 2 кластеру
# 19     Обучение на разнице ЭЛО по 2 кластеру
# 20     Обучение на среднем ЭЛО по 3 кластеру
# 21     Обучение на разнице ЭЛО по 3 кластеру
# 22     Обучение на среднем ЭЛО по 4 кластеру
# 23     Обучение на разнице ЭЛО по 4 кластеру
# 24     Обучение на среднем ЭЛО по 1 кластеру
# 25     Обучение на разнице ЭЛО по 1 кластеру
# 26     Обучение на среднем ЭЛО по 2 кластеру
# 27     Обучение на разнице ЭЛО по 2 кластеру
# 28     Обучение на среднем ЭЛО по 3 кластеру
# 29     Обучение на разнице ЭЛО по 3 кластеру
# 30     Обучение на среднем ЭЛО по 4 кластеру
# 31     Обучение на разнице ЭЛО по 4 кластеру
# 32     Обучение на среднем ЭЛО по 1 кластеру
# 33     Обучение на разнице ЭЛО по 1 кластеру
# 34     Обучение на среднем ЭЛО по 2 кластеру
# 35     Обучение на разнице ЭЛО по 2 кластеру
# 36     Обучение на среднем ЭЛО по 3 кластеру
# 37     Обучение на разнице ЭЛО по 3 кластеру
# 38     Обучение на среднем ЭЛО по 4 кластеру
# 39     Обучение на разнице ЭЛО по 4 кластеру

# %%
white_elos_4 = knr_pred7 + knr_pred8/2
black_elos_4 = knr_pred7-knr_pred8/2
pred_elos4=list(zip(white_elos_4,black_elos_4))
print(len(pred_elos4))
pred_elos4[:5]
# Out:
# 426
# [(2118.093823911875, 2158.760490578542),
#  (2531.1824484758745, 2527.5157818092075),
#  (2295.323861461921, 2417.657194795254),
#  (2253.084114517355, 2299.084114517355),
#  (2085.362061545083, 1891.6953948784164)]

# %%
find_abs_error(pred_elos4,elos_4),find_mean_error(pred_elos4,elos_4),find_root_mean_squared_error(pred_elos4,elos_4)
# Out:
# (236656.085, 277.765, 343.648)

# %%
inner_mae_4=find_mean_error(pred_elos4,elos_4)

# %%
errors =errors.append(pd.Series(['4 кластер','K-Neighbors',find_abs_error(pred_elos4,elos_4),
                                 find_mean_error(pred_elos4,elos_4),
                                 find_root_mean_squared_error(pred_elos4,elos_4)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE         RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06   189.45700    237.56700
# 1      2 кластер  LinearRegression       2.481410e+05   180.86100    228.08700
# 2      3 кластер  LinearRegression       5.772583e+04   126.03900    162.09500
# 3      4 кластер  LinearRegression       5.350485e+05   188.53000    237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06   171.22175    216.26225
# 5      1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 6      2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 7      3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 8      4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 10     1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 11     2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 12     3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 13     4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 15     1 кластер        ElasticNet       3.676407e+06   279.49000    360.94600
# 16     2 кластер        ElasticNet       2.794689e+05   678.32300    865.25800
# 17     3 кластер        ElasticNet       7.453663e+05  5401.20500  45543.50900
# 18     4 кластер        ElasticNet       3.233976e+05   379.57500   1427.39000
# 19  Общая ошибка        ElasticNet       1.256160e+06  1684.64825  12049.27575
# 20     1 кластер       K-Neighbors       3.453795e+06   262.56600    329.65800
# 21     2 кластер       K-Neighbors       2.774274e+05   673.36700    841.52500
# 22     3 кластер       K-Neighbors       3.887068e+04   281.67200    348.71400
# 23     4 кластер       K-Neighbors       2.366561e+05   277.76500    343.64800

# %%
knr_mae=(inner_mae_4+inner_mae_3+inner_mae_2+inner_mae_1)/4
knr_mae
# Out:
# 373.84250000000003

# %%
knr_abs=(find_abs_error(pred_elos1,elos_1)+
        find_abs_error(pred_elos2,elos_2)+
        find_abs_error(pred_elos3,elos_3)+
        find_abs_error(pred_elos4,elos_4))/4
knr_abs
# Out:
# 1001687.2487499999

# %%
knr_rmse=(find_root_mean_squared_error(pred_elos1,elos_1)+
         find_root_mean_squared_error(pred_elos2,elos_2)+
         find_root_mean_squared_error(pred_elos3,elos_3)+
         find_root_mean_squared_error(pred_elos4,elos_4))/4
knr_rmse
# Out:
# 465.88625

# %%
errors = errors.append(pd.Series(['Общая ошибка','K-Neighbors',
                  knr_abs,
                  knr_mae,
                 knr_rmse],index=errors.columns) ,ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE         RMSE
# 0      1 Кластер  LinearRegression       8.306192e+06   189.45700    237.56700
# 1      2 кластер  LinearRegression       2.481410e+05   180.86100    228.08700
# 2      3 кластер  LinearRegression       5.772583e+04   126.03900    162.09500
# 3      4 кластер  LinearRegression       5.350485e+05   188.53000    237.30000
# 4   Общая ошибка  LinearRegression       2.286777e+06   171.22175    216.26225
# 5      1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 6      2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 7      3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 8      4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 9   Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 10     1 кластер          AdaBoost       3.217283e+06   244.58600    306.16900
# 11     2 кластер          AdaBoost       2.810322e+05   682.11700    886.27600
# 12     3 кластер          AdaBoost       5.346101e+04   387.39900    479.34900
# 13     4 кластер          AdaBoost       3.108843e+05   364.88800    454.87300
# 14  Общая ошибка          AdaBoost       9.656651e+05   419.74750    531.66675
# 15     1 кластер        ElasticNet       3.676407e+06   279.49000    360.94600
# 16     2 кластер        ElasticNet       2.794689e+05   678.32300    865.25800
# 17     3 кластер        ElasticNet       7.453663e+05  5401.20500  45543.50900
# 18     4 кластер        ElasticNet       3.233976e+05   379.57500   1427.39000
# 19  Общая ошибка        ElasticNet       1.256160e+06  1684.64825  12049.27575
# 20     1 кластер       K-Neighbors       3.453795e+06   262.56600    329.65800
# 21     2 кластер       K-Neighbors       2.774274e+05   673.36700    841.52500
# 22     3 кластер       K-Neighbors       3.887068e+04   281.67200    348.71400
# 23     4 кластер       K-Neighbors       2.366561e+05   277.76500    343.64800
# 24  Общая ошибка       K-Neighbors       1.001687e+06   373.84250    465.88625
