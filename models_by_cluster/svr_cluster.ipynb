# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.svm import SVR
from sklearn import model_selection as ms
from scipy.stats import pearsonr
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.feature_selection import VarianceThreshold

rand_st=4

# %%
output=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx')
errors=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx')

# %%
elos_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos1.csv')
elos_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos2.csv')
elos_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos3.csv')
elos_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos4.csv')
features_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features1.csv')
features_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features3.csv')
features_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features2.csv')
features_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features4.csv')

# %%
X_train_mean_1, X_test_mean_1, Y_train_mean_1, Y_test_mean_1 =ms.train_test_split(features_1, elos_1['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_1, X_test_diff_1, Y_train_diff_1, Y_test_diff_1 =ms.train_test_split(features_1, elos_1['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_2, X_test_mean_2, Y_train_mean_2, Y_test_mean_2 =ms.train_test_split(features_2, elos_2['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_2, X_test_diff_2, Y_train_diff_2, Y_test_diff_2 =ms.train_test_split(features_2, elos_2['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_3, X_test_mean_3, Y_train_mean_3, Y_test_mean_3 =ms.train_test_split(features_3, elos_3['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_3, X_test_diff_3, Y_train_diff_3, Y_test_diff_3 =ms.train_test_split(features_3, elos_3['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_4, X_test_mean_4, Y_train_mean_4, Y_test_mean_4 =ms.train_test_split(features_4, elos_4['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_4, X_test_diff_4, Y_train_diff_4, Y_test_diff_4 =ms.train_test_split(features_4, elos_4['DiffElos'], test_size = 0.3,random_state=rand_st)

# %%
model_mean=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
              kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

model_diff=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
          kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
def find_mean_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
        count+=2
    return round(er/count,3)

def find_abs_error(pred,elos):
    er=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
    return round(er,3)

def find_root_mean_squared_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=(elos.iloc[ind,0]-val[0])**2
        er+=(elos.iloc[ind,1]-val[1])**2
        count+=2
    return round((er/count)**0.5,3)

# %%
def predictions_report(pred_target,predictions):
    mae_report=mae(pred_target,predictions)
    print ('MAE = {:.3f}'.format(mae_report))
    
    rmse_report = (mse(pred_target, predictions))**0.5
    print ('RMSE = {:.3f}'.format(rmse_report))
    
    corr_coef = pearsonr(pred_target,predictions)
    print("Correlation coefficient = {:.3f}".format(corr_coef[0]))
    
    return (mae_report,rmse_report,corr_coef)

# %% [markdown]
# ### Подбор модели для 1 кластера

# %%
start1 = time.time()

svr1=model_mean.fit(X_train_mean_1,Y_train_mean_1)
svr_pred1=svr1.predict(X_test_mean_1)
scores1=predictions_report(Y_test_mean_1,svr_pred1)
full_time1=round(time.time() - start1,3)
print(full_time1, 'c')
# Out:
# MAE = 108.127
# RMSE = 141.653
# Correlation coefficient = nan
# 4.502 c
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores1[0],scores1[1], 
                                 scores1[2][0],full_time1,'Обучение на среднем ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                    0.310189             0.026
# 1                    0.564917             0.032
# 2                    0.217573             0.040
# 3                    0.501589             0.039
# 4                    0.237813             0.040
# 5                    0.390109             0.028
# 6                    0.228683             0.028
# 7                    0.404880             0.037
# 8                    0.269526            15.508
# 9                    0.527370             7.519
# 10                   0.196935            35.547
# 11                   0.463962            24.118
# 12                   0.149177            25.474
# 13                   0.367790            13.734
# 14                   0.109938            21.127
# 15                   0.386076            13.272
# 16                   0.094026            11.439
# 17                   0.094026            11.205
# 18                   0.441198             1.771
# 19                   0.115520            34.275
# 20                   0.395729             3.448
# 21                   0.130682            23.751
# 22                   0.161799             2.169
# 23                   0.028956            23.867
# 24                   0.302327             2.246
# 25                   0.243967           609.683
# 26                   0.542367           441.770
# 27                   0.174233          1328.309
# 28                   0.495507          1268.388
# 29                   0.149890           892.593
# 30                   0.344812           851.510
# 31                   0.130162           802.207
# 32                   0.381572           763.881
# 33                  -0.011688             0.478
# 34                   0.279341             0.135
# 35                  -0.001899             0.181
# 36                   0.289641             0.288
# 37                   0.005160             0.158
# 38                   0.192296             0.145
# 39                   0.036735             0.160
# 40                   0.210277             0.163
# 41                        NaN             4.502
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру

# %%
start2 = time.time()

svr2=model_diff.fit(X_train_diff_1,Y_train_diff_1)
svr_pred2=svr2.predict(X_test_mean_1)
scores2=predictions_report(Y_test_diff_1,svr_pred2)
full_time2=round(time.time() - start2,3)
print(full_time2, 'c')
# Out:
# MAE = 224.493
# RMSE = 263.468
# Correlation coefficient = 0.000
# 5.053 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores2[0],scores2[1], 
                                 scores2[2][0],full_time2,'Обучение на разнице ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_1 = svr_pred1 + svr_pred2/2
black_elos_1 = svr_pred1-svr_pred2/2
pred_elos1=list(zip(white_elos_1,black_elos_1))
print(len(pred_elos1))
pred_elos1[:5]
# Out:
# 1279
# [(1900.8544444444442, 1890.034444444444),
#  (1900.8544444444442, 1890.034444444444),
#  (1900.8544444444442, 1890.034444444444),
#  (1900.8544444444442, 1890.034444444444),
#  (1900.8544444444442, 1890.034444444444)]

# %%
find_abs_error(pred_elos1,elos_1),find_mean_error(pred_elos1,elos_1),find_root_mean_squared_error(pred_elos1,elos_1)
# Out:
# (390673.191, 152.726, 193.326)

# %%
inner_mae_1=find_mean_error(pred_elos1,elos_1)

# %%
errors =errors.append(pd.Series(['1 кластер','SVM',
                  find_abs_error(pred_elos1,elos_1),
                  find_mean_error(pred_elos1,elos_1),
                   find_root_mean_squared_error(pred_elos1,elos_1) ],
                                   index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06  134.93600  168.90800
# 1      2 кластер  LinearRegression       1.566282e+06   95.28400  117.43700
# 2      3 кластер  LinearRegression       1.127526e+06   94.55900  115.89300
# 3      4 кластер  LinearRegression       1.099642e+06   94.60100  116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06  104.84500  129.63325
# 5      1 кластер     Random Forest       4.042465e+05  158.03200  195.80200
# 6      2 кластер     Random Forest       3.344622e+06  678.14700  893.17400
# 7      3 кластер     Random Forest       3.570672e+05   99.79500  122.90600
# 8      4 кластер     Random Forest       3.539965e+05  101.49000  125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06  259.36600  334.37800
# 10     1 кластер          AdaBoost       4.870781e+05  190.41400  246.69200
# 11     2 кластер          AdaBoost       3.521219e+06  713.95400  934.84000
# 12     3 кластер          AdaBoost       3.667591e+05  102.50400  126.69600
# 13     4 кластер          AdaBoost       3.640111e+05  104.36100  128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06  277.80825  359.29500
# 15     1 кластер       Extra Trees       4.225951e+05  165.20500  204.97800
# 16     2 кластер       Extra Trees       3.367925e+06  682.87200  897.57900
# 17     3 кластер       Extra Trees       3.676035e+05  102.74000  126.27200
# 18     4 кластер       Extra Trees       3.628531e+05  104.02900  128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06  263.71150  339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05  184.28800  231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06  687.46900  897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05  116.15700  144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05  120.59700  150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06  277.12775  355.85450
# 25     1 кластер               SVM       3.906732e+05  152.72600  193.32600

# %%
errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)

# %% [markdown]
# ### Подбор модели для 2 кластера

# %%
start3 = time.time()

svr3=model_mean.fit(X_train_mean_2,Y_train_mean_2)
svr_pred3=svr3.predict(X_test_mean_2)
scores3=predictions_report(Y_test_mean_2,svr_pred3)
full_time3=round(time.time() - start3,3)
print(full_time3, 'c')
# Out:
# MAE = 77.804
# RMSE = 98.050
# Correlation coefficient = -0.047
# 16.371 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores3[0],scores3[1], 
                                 scores3[2][0],full_time3,'Обучение на среднем ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру

# %%
start4 = time.time()

svr4=model_diff.fit(X_train_diff_2,Y_train_diff_2)
svr_pred4=svr4.predict(X_test_mean_2)
scores4=predictions_report(Y_test_diff_2,svr_pred4)
full_time4=round(time.time() - start4,3)
print(full_time4, 'c')
# Out:
# MAE = 128.099
# RMSE = 157.256
# Correlation coefficient = 0.013
# 16.042 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores4[0],scores4[1], 
                                 scores4[2][0],full_time4,'Обучение на разнице ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  128.099075  157.256146
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
# 44               1.330685e-02            16.042
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_2 = svr_pred3 + svr_pred3/2
black_elos_2 = svr_pred3-svr_pred4/2
pred_elos2=list(zip(white_elos_2,black_elos_2))
print(len(pred_elos2))
pred_elos2[:5]
# Out:
# 2466
# [(3716.640000000004, 2474.8750000000023),
#  (3716.640000000004, 2474.8750000000023),
#  (3716.640000000004, 2474.8750000000023),
#  (3716.640000000004, 2474.8750000000023),
#  (3716.640000000004, 2474.8750000000023)]

# %%
find_abs_error(pred_elos2,elos_2),find_mean_error(pred_elos2,elos_2),find_root_mean_squared_error(pred_elos2,elos_2)
# Out:
# (3269403.99, 662.896, 873.151)

# %%
inner_mae_2=find_mean_error(pred_elos2,elos_2)

# %%
errors =errors.append(pd.Series(['2 кластер','SVM',
                        find_abs_error(pred_elos2,elos_2),
                        find_mean_error(pred_elos2,elos_2),
                        find_root_mean_squared_error(pred_elos2,elos_2)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06  134.93600  168.90800
# 1      2 кластер  LinearRegression       1.566282e+06   95.28400  117.43700
# 2      3 кластер  LinearRegression       1.127526e+06   94.55900  115.89300
# 3      4 кластер  LinearRegression       1.099642e+06   94.60100  116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06  104.84500  129.63325
# 5      1 кластер     Random Forest       4.042465e+05  158.03200  195.80200
# 6      2 кластер     Random Forest       3.344622e+06  678.14700  893.17400
# 7      3 кластер     Random Forest       3.570672e+05   99.79500  122.90600
# 8      4 кластер     Random Forest       3.539965e+05  101.49000  125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06  259.36600  334.37800
# 10     1 кластер          AdaBoost       4.870781e+05  190.41400  246.69200
# 11     2 кластер          AdaBoost       3.521219e+06  713.95400  934.84000
# 12     3 кластер          AdaBoost       3.667591e+05  102.50400  126.69600
# 13     4 кластер          AdaBoost       3.640111e+05  104.36100  128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06  277.80825  359.29500
# 15     1 кластер       Extra Trees       4.225951e+05  165.20500  204.97800
# 16     2 кластер       Extra Trees       3.367925e+06  682.87200  897.57900
# 17     3 кластер       Extra Trees       3.676035e+05  102.74000  126.27200
# 18     4 кластер       Extra Trees       3.628531e+05  104.02900  128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06  263.71150  339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05  184.28800  231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06  687.46900  897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05  116.15700  144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05  120.59700  150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06  277.12775  355.85450
# 25     1 кластер               SVM       3.906732e+05  152.72600  193.32600
# 26     2 кластер               SVM       3.269404e+06  662.89600  873.15100

# %% [markdown]
# ### Подбор модели для 3 кластера

# %%
start5 = time.time()

svr5=model_mean.fit(X_train_mean_3,Y_train_mean_3)
svr_pred5=svr5.predict(X_test_mean_3)
scores5=predictions_report(Y_test_mean_3,svr_pred5)
full_time5=round(time.time() - start5,3)
print(full_time5, 'c')
# Out:
# MAE = 83.555
# RMSE = 97.614
# Correlation coefficient = 0.003
# 6.731 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores5[0],scores5[1], 
                                 scores5[2][0],full_time5,'Обучение на среднем ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  128.099075  157.256146
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   83.554723   97.613693
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
# 44               1.330685e-02            16.042
# 45               3.165276e-03             6.731
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру

# %%
start6 = time.time()

svr6=model_diff.fit(X_train_diff_3,Y_train_diff_3)
svr_pred6=svr6.predict(X_test_mean_3)
scores6=predictions_report(Y_test_diff_3,svr_pred6)
full_time6=round(time.time() - start6,3)
print(full_time6, 'c')
# Out:
# MAE = 111.497
# RMSE = 145.735
# Correlation coefficient = 0.001
# 6.693 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores6[0],scores6[1], 
                                 scores6[2][0],full_time6,'Обучение на разнице ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  128.099075  157.256146
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   83.554723   97.613693
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  111.496710  145.735266
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
# 44               1.330685e-02            16.042
# 45               3.165276e-03             6.731
# 46               7.482165e-04             6.693
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_3 = svr_pred5 + svr_pred6/2
black_elos_3 = svr_pred5-svr_pred6/2
pred_elos3=list(zip(white_elos_3,black_elos_3))
print(len(pred_elos3))
pred_elos3[:5]
# Out:
# 1789
# [(2304.3309523809535, 2097.2690476190487),
#  (2304.3309523809535, 2097.2690476190487),
#  (2304.3309523809535, 2097.2690476190487),
#  (2304.3309523809535, 2097.2690476190487),
#  (2304.3309523809535, 2097.2690476190487)]

# %%
find_abs_error(pred_elos3,elos_3),find_mean_error(pred_elos3,elos_3),find_root_mean_squared_error(pred_elos3,elos_3)
# Out:
# (353735.948, 98.864, 121.666)

# %%
inner_mae_3=find_mean_error(pred_elos3,elos_3)

# %%
errors =errors.append(pd.Series(['3 кластер','SVM',
                                 find_abs_error(pred_elos3,elos_3),
                                 find_mean_error(pred_elos3,elos_3),
                                 find_root_mean_squared_error(pred_elos3,elos_3)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06  134.93600  168.90800
# 1      2 кластер  LinearRegression       1.566282e+06   95.28400  117.43700
# 2      3 кластер  LinearRegression       1.127526e+06   94.55900  115.89300
# 3      4 кластер  LinearRegression       1.099642e+06   94.60100  116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06  104.84500  129.63325
# 5      1 кластер     Random Forest       4.042465e+05  158.03200  195.80200
# 6      2 кластер     Random Forest       3.344622e+06  678.14700  893.17400
# 7      3 кластер     Random Forest       3.570672e+05   99.79500  122.90600
# 8      4 кластер     Random Forest       3.539965e+05  101.49000  125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06  259.36600  334.37800
# 10     1 кластер          AdaBoost       4.870781e+05  190.41400  246.69200
# 11     2 кластер          AdaBoost       3.521219e+06  713.95400  934.84000
# 12     3 кластер          AdaBoost       3.667591e+05  102.50400  126.69600
# 13     4 кластер          AdaBoost       3.640111e+05  104.36100  128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06  277.80825  359.29500
# 15     1 кластер       Extra Trees       4.225951e+05  165.20500  204.97800
# 16     2 кластер       Extra Trees       3.367925e+06  682.87200  897.57900
# 17     3 кластер       Extra Trees       3.676035e+05  102.74000  126.27200
# 18     4 кластер       Extra Trees       3.628531e+05  104.02900  128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06  263.71150  339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05  184.28800  231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06  687.46900  897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05  116.15700  144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05  120.59700  150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06  277.12775  355.85450
# 25     1 кластер               SVM       3.906732e+05  152.72600  193.32600
# 26     2 кластер               SVM       3.269404e+06  662.89600  873.15100
# 27     3 кластер               SVM       3.537359e+05   98.86400  121.66600

# %% [markdown]
# ### Подбор модели для 4 кластера

# %%
start7 = time.time()

svr7=model_mean.fit(X_train_mean_4,Y_train_mean_4)
svr_pred7=svr7.predict(X_test_mean_4)
scores7=predictions_report(Y_test_mean_4,svr_pred7)
full_time7=round(time.time() - start7,3)
print(full_time7, 'c')
# Out:
# MAE = 82.824
# RMSE = 97.198
# Correlation coefficient = -0.015
# 6.398 c

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores7[0],scores7[1], 
                                 scores7[2][0],full_time7,'Обучение на среднем ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  128.099075  157.256146
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   83.554723   97.613693
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  111.496710  145.735266
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   82.823595   97.197577
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
# 44               1.330685e-02            16.042
# 45               3.165276e-03             6.731
# 46               7.482165e-04             6.693
# 47              -1.473657e-02             6.398
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру

# %%
start8 = time.time()

svr8=model_diff.fit(X_train_diff_4,Y_train_diff_4)
svr_pred8=svr8.predict(X_test_mean_4)
scores8=predictions_report(Y_test_diff_4,svr_pred8)
full_time8=round(time.time() - start8,3)
print(full_time8, 'c')
# Out:
# MAE = 111.114
# RMSE = 147.938
# Correlation coefficient = 0.014
# 6.553 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores8[0],scores8[1], 
                                 scores8[2][0],full_time8,'Обучение на разнице ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель         MAE        RMSE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...  102.980777  129.002684
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...  173.676816  218.061005
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...   77.387126   95.797568
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...  108.608625  135.853982
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...   80.616755   94.974990
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...  102.869006  132.827010
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...   80.319818   94.829941
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...  103.741893  134.630404
# 8   RandomForestRegressor(bootstrap=False, criteri...  106.924601  132.042952
# 9   RandomForestRegressor(bootstrap=True, criterio...  188.770360  229.315473
# 10  RandomForestRegressor(bootstrap=False, criteri...   77.401777   94.899905
# 11  RandomForestRegressor(bootstrap=True, criterio...  114.877201  142.274351
# 12  RandomForestRegressor(bootstrap=False, criteri...   82.135211   96.557585
# 13  RandomForestRegressor(bootstrap=True, criterio...  105.325596  137.163947
# 14  RandomForestRegressor(bootstrap=False, criteri...   82.580581   96.617983
# 15  RandomForestRegressor(bootstrap=True, criterio...  104.476313  137.892647
# 16  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 17  AdaBoostRegressor(base_estimator=None, learnin...  142.565262  193.350924
# 18  AdaBoostRegressor(base_estimator=None, learnin...  193.257287  239.085315
# 19  AdaBoostRegressor(base_estimator=None, learnin...   88.687588  104.757972
# 20  AdaBoostRegressor(base_estimator=None, learnin...  119.551083  149.883409
# 21  AdaBoostRegressor(base_estimator=None, learnin...   82.589497   97.541636
# 22  AdaBoostRegressor(base_estimator=None, learnin...  111.373776  148.493845
# 23  AdaBoostRegressor(base_estimator=None, learnin...   84.292219   98.517209
# 24  AdaBoostRegressor(base_estimator=None, learnin...  107.480968  140.256347
# 25  ExtraTreesRegressor(bootstrap=False, criterion...  108.276760  133.103928
# 26  ExtraTreesRegressor(bootstrap=False, criterion...  177.682547  221.421097
# 27  ExtraTreesRegressor(bootstrap=False, criterion...   78.237451   95.555050
# 28  ExtraTreesRegressor(bootstrap=False, criterion...  109.402946  136.596378
# 29  ExtraTreesRegressor(bootstrap=False, criterion...   82.136358   96.627399
# 30  ExtraTreesRegressor(bootstrap=False, criterion...  107.407830  136.446247
# 31  ExtraTreesRegressor(bootstrap=False, criterion...   82.310229   96.355749
# 32  ExtraTreesRegressor(bootstrap=False, criterion...  105.467436  135.471461
# 33  KNeighborsRegressor(algorithm='auto', leaf_siz...  133.708909  168.964180
# 34  KNeighborsRegressor(algorithm='auto', leaf_siz...  221.114934  272.234883
# 35  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.565813  120.113983
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...  129.531225  162.911876
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...   97.339096  119.402582
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...  121.579094  154.974859
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...   95.921131  117.628118
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...  122.630925  157.465849
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  108.126575  141.652915
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  224.492744  263.467992
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   77.803844   98.049764
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  128.099075  157.256146
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   83.554723   97.613693
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  111.496710  145.735266
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   82.823595   97.197577
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...  111.114220  147.937638
#
#     Коэффициент корр. Пирсона  Время работы (c)  \
# 0                3.101891e-01             0.026
# 1                5.649173e-01             0.032
# 2                2.175725e-01             0.040
# 3                5.015886e-01             0.039
# 4                2.378129e-01             0.040
# 5                3.901095e-01             0.028
# 6                2.286831e-01             0.028
# 7                4.048796e-01             0.037
# 8                2.695258e-01            15.508
# 9                5.273697e-01             7.519
# 10               1.969347e-01            35.547
# 11               4.639618e-01            24.118
# 12               1.491770e-01            25.474
# 13               3.677896e-01            13.734
# 14               1.099377e-01            21.127
# 15               3.860759e-01            13.272
# 16               9.402648e-02            11.439
# 17               9.402648e-02            11.205
# 18               4.411977e-01             1.771
# 19               1.155195e-01            34.275
# 20               3.957288e-01             3.448
# 21               1.306815e-01            23.751
# 22               1.617992e-01             2.169
# 23               2.895609e-02            23.867
# 24               3.023271e-01             2.246
# 25               2.439675e-01           609.683
# 26               5.423671e-01           441.770
# 27               1.742332e-01          1328.309
# 28               4.955065e-01          1268.388
# 29               1.498900e-01           892.593
# 30               3.448121e-01           851.510
# 31               1.301624e-01           802.207
# 32               3.815718e-01           763.881
# 33              -1.168850e-02             0.478
# 34               2.793407e-01             0.135
# 35              -1.899401e-03             0.181
# 36               2.896413e-01             0.288
# 37               5.159687e-03             0.158
# 38               1.922963e-01             0.145
# 39               3.673458e-02             0.160
# 40               2.102769e-01             0.163
# 41                        NaN             4.502
# 42               4.993194e-17             5.053
# 43              -4.655160e-02            16.371
# 44               1.330685e-02            16.042
# 45               3.165276e-03             6.731
# 46               7.482165e-04             6.693
# 47              -1.473657e-02             6.398
# 48               1.381398e-02             6.553
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# 30     Обучение на разнице ЭЛО по 3 кластеру
# 31     Обучение на среднем ЭЛО по 4 кластеру
# 32     Обучение на разнице ЭЛО по 4 кластеру
# 33     Обучение на среднем ЭЛО по 1 кластеру
# 34     Обучение на разнице ЭЛО по 1 кластеру
# 35     Обучение на среднем ЭЛО по 2 кластеру
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру

# %%
white_elos_4 = svr_pred7 + svr_pred8/2
black_elos_4 = svr_pred7-svr_pred8/2
pred_elos4=list(zip(white_elos_4,black_elos_4))
print(len(pred_elos4))
pred_elos4[:5]
# Out:
# 1744
# [(2118.682142857144, 2314.1678571428583),
#  (2118.682142857144, 2314.1678571428583),
#  (2118.682142857144, 2314.1678571428583),
#  (2118.682142857144, 2314.1678571428583),
#  (2118.682142857144, 2314.1678571428583)]

# %%
find_abs_error(pred_elos4,elos_4),find_mean_error(pred_elos4,elos_4),find_root_mean_squared_error(pred_elos4,elos_4)
# Out:
# (349644.514, 100.242, 124.08)

# %%
inner_mae_4=find_mean_error(pred_elos4,elos_4)

# %%
errors =errors.append(pd.Series(['4 кластер','SVM',find_abs_error(pred_elos4,elos_4),
                                 find_mean_error(pred_elos4,elos_4),
                                 find_root_mean_squared_error(pred_elos4,elos_4)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06  134.93600  168.90800
# 1      2 кластер  LinearRegression       1.566282e+06   95.28400  117.43700
# 2      3 кластер  LinearRegression       1.127526e+06   94.55900  115.89300
# 3      4 кластер  LinearRegression       1.099642e+06   94.60100  116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06  104.84500  129.63325
# 5      1 кластер     Random Forest       4.042465e+05  158.03200  195.80200
# 6      2 кластер     Random Forest       3.344622e+06  678.14700  893.17400
# 7      3 кластер     Random Forest       3.570672e+05   99.79500  122.90600
# 8      4 кластер     Random Forest       3.539965e+05  101.49000  125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06  259.36600  334.37800
# 10     1 кластер          AdaBoost       4.870781e+05  190.41400  246.69200
# 11     2 кластер          AdaBoost       3.521219e+06  713.95400  934.84000
# 12     3 кластер          AdaBoost       3.667591e+05  102.50400  126.69600
# 13     4 кластер          AdaBoost       3.640111e+05  104.36100  128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06  277.80825  359.29500
# 15     1 кластер       Extra Trees       4.225951e+05  165.20500  204.97800
# 16     2 кластер       Extra Trees       3.367925e+06  682.87200  897.57900
# 17     3 кластер       Extra Trees       3.676035e+05  102.74000  126.27200
# 18     4 кластер       Extra Trees       3.628531e+05  104.02900  128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06  263.71150  339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05  184.28800  231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06  687.46900  897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05  116.15700  144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05  120.59700  150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06  277.12775  355.85450
# 25     1 кластер               SVM       3.906732e+05  152.72600  193.32600
# 26     2 кластер               SVM       3.269404e+06  662.89600  873.15100
# 27     3 кластер               SVM       3.537359e+05   98.86400  121.66600
# 28     4 кластер               SVM       3.496445e+05  100.24200  124.08000

# %%
svr_mae=(inner_mae_4+inner_mae_3+inner_mae_2+inner_mae_1)/4
svr_mae
# Out:
# 253.682

# %%
svr_abs=(find_abs_error(pred_elos1,elos_1)+
        find_abs_error(pred_elos2,elos_2)+
        find_abs_error(pred_elos3,elos_3)+
        find_abs_error(pred_elos4,elos_4))/4
svr_abs
# Out:
# 1090864.41075

# %%
svr_rmse=(find_root_mean_squared_error(pred_elos1,elos_1)+
         find_root_mean_squared_error(pred_elos2,elos_2)+
         find_root_mean_squared_error(pred_elos3,elos_3)+
         find_root_mean_squared_error(pred_elos4,elos_4))/4
svr_rmse
# Out:
# 328.05574999999993

# %%
errors = errors.append(pd.Series(['Общая ошибка','SVM',
                  svr_abs,
                  svr_mae,
                 svr_rmse],index=errors.columns) ,ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка        MAE       RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06  134.93600  168.90800
# 1      2 кластер  LinearRegression       1.566282e+06   95.28400  117.43700
# 2      3 кластер  LinearRegression       1.127526e+06   94.55900  115.89300
# 3      4 кластер  LinearRegression       1.099642e+06   94.60100  116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06  104.84500  129.63325
# 5      1 кластер     Random Forest       4.042465e+05  158.03200  195.80200
# 6      2 кластер     Random Forest       3.344622e+06  678.14700  893.17400
# 7      3 кластер     Random Forest       3.570672e+05   99.79500  122.90600
# 8      4 кластер     Random Forest       3.539965e+05  101.49000  125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06  259.36600  334.37800
# 10     1 кластер          AdaBoost       4.870781e+05  190.41400  246.69200
# 11     2 кластер          AdaBoost       3.521219e+06  713.95400  934.84000
# 12     3 кластер          AdaBoost       3.667591e+05  102.50400  126.69600
# 13     4 кластер          AdaBoost       3.640111e+05  104.36100  128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06  277.80825  359.29500
# 15     1 кластер       Extra Trees       4.225951e+05  165.20500  204.97800
# 16     2 кластер       Extra Trees       3.367925e+06  682.87200  897.57900
# 17     3 кластер       Extra Trees       3.676035e+05  102.74000  126.27200
# 18     4 кластер       Extra Trees       3.628531e+05  104.02900  128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06  263.71150  339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05  184.28800  231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06  687.46900  897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05  116.15700  144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05  120.59700  150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06  277.12775  355.85450
# 25     1 кластер               SVM       3.906732e+05  152.72600  193.32600
# 26     2 кластер               SVM       3.269404e+06  662.89600  873.15100
# 27     3 кластер               SVM       3.537359e+05   98.86400  121.66600
# 28     4 кластер               SVM       3.496445e+05  100.24200  124.08000
# 29  Общая ошибка               SVM       1.090864e+06  253.68200  328.05575
