# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from xgboost import XGBRegressor
from sklearn import model_selection as ms
from scipy.stats import pearsonr
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.feature_selection import VarianceThreshold

rand_st=4

# %%
output=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx')
errors=pd.read_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx')

# %%
elos_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos1.csv')
elos_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos2.csv')
elos_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos3.csv')
elos_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\elos4.csv')
features_1=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features1.csv')
features_3=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features3.csv')
features_2=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features2.csv')
features_4=pd.read_csv(r'C:\Users\Asus\PredictingRatings\data\features4.csv')

# %%
X_train_mean_1, X_test_mean_1, Y_train_mean_1, Y_test_mean_1 =ms.train_test_split(features_1, elos_1['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_1, X_test_diff_1, Y_train_diff_1, Y_test_diff_1 =ms.train_test_split(features_1, elos_1['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_2, X_test_mean_2, Y_train_mean_2, Y_test_mean_2 =ms.train_test_split(features_2, elos_2['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_2, X_test_diff_2, Y_train_diff_2, Y_test_diff_2 =ms.train_test_split(features_2, elos_2['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_3, X_test_mean_3, Y_train_mean_3, Y_test_mean_3 =ms.train_test_split(features_3, elos_3['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_3, X_test_diff_3, Y_train_diff_3, Y_test_diff_3 =ms.train_test_split(features_3, elos_3['DiffElos'], test_size = 0.3,random_state=rand_st)

X_train_mean_4, X_test_mean_4, Y_train_mean_4, Y_test_mean_4 =ms.train_test_split(features_4, elos_4['MeanElos'], test_size = 0.3,random_state=rand_st)
X_train_diff_4, X_test_diff_4, Y_train_diff_4, Y_test_diff_4 =ms.train_test_split(features_4, elos_4['DiffElos'], test_size = 0.3,random_state=rand_st)

# %%
model_mean=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bytree=1, gamma=0, importance_type='gain',
             learning_rate=0, max_delta_step=0, max_depth=3, min_child_weight=1,
             missing=None, n_estimators=50, n_jobs=1, nthread=4,
             objective='reg:linear', random_state=0, reg_alpha=0, reg_lambda=1,
             scale_pos_weight=1, seed=4, silent=True, subsample=0.2)

model_diff=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bytree=1, gamma=0.9, importance_type='gain',
             learning_rate=0.5, max_delta_step=0, max_depth=15,
             min_child_weight=1, missing=None, n_estimators=50, n_jobs=1,
             nthread=4, objective='reg:linear', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, seed=4, silent=True,
             subsample=0.2)

# %%
def find_mean_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
        count+=2
    return round(er/count,3)

def find_abs_error(pred,elos):
    er=0
    for ind, val in enumerate(pred):
        er+=abs(elos.iloc[ind,0]-val[0])
        er+=abs(elos.iloc[ind,1]-val[1])
    return round(er,3)

def find_root_mean_squared_error(pred,elos):
    er=0
    count=0
    for ind, val in enumerate(pred):
        er+=(elos.iloc[ind,0]-val[0])**2
        er+=(elos.iloc[ind,1]-val[1])**2
        count+=2
    return round((er/count)**0.5,3)

# %%
def predictions_report(pred_target,predictions):
    mae_report=mae(pred_target,predictions)
    print ('MAE = {:.3f}'.format(mae_report))
    
    rmse_report = (mse(pred_target, predictions))**0.5
    print ('RMSE = {:.3f}'.format(rmse_report))
    
    corr_coef = pearsonr(pred_target,predictions)
    print("Correlation coefficient = {:.3f}".format(corr_coef[0]))
    
    return (mae_report,rmse_report,corr_coef)

# %% [markdown]
# ### Подбор модели для 1 кластера

# %%
start1 = time.time()

xgb1=model_mean.fit(X_train_mean_1,Y_train_mean_1)
xgb_pred1=xgb1.predict(X_test_mean_1)
scores1=predictions_report(Y_test_mean_1,xgb_pred1)
full_time1=round(time.time() - start1,3)
print(full_time1, 'c')
# Out:
# MAE = 1858.638
# RMSE = 1863.675
# Correlation coefficient = nan
# 0.216 c
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores1[0],scores1[1], 
                                 scores1[2][0],full_time1,'Обучение на среднем ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 36  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 36   162.911876               2.896413e-01             0.288
# 37   119.402582               5.159687e-03             0.158
# 38   154.974859               1.922963e-01             0.145
# 39   117.628118               3.673458e-02             0.160
# 40   157.465849               2.102769e-01             0.163
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 36     Обучение на разнице ЭЛО по 2 кластеру
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
#
# [66 rows x 6 columns]

# %%
start2 = time.time()

xgb2=model_diff.fit(X_train_diff_1,Y_train_diff_1)
xgb_pred2=xgb2.predict(X_test_mean_1)
scores2=predictions_report(Y_test_diff_1,xgb_pred2)
full_time2=round(time.time() - start2,3)
print(full_time2, 'c')
# Out:
# MAE = 533.075
# RMSE = 668.593
# Correlation coefficient = 0.118
# 1.27 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores2[0],scores2[1], 
                                 scores2[2][0],full_time2,'Обучение на разнице ЭЛО по 1 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 37  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 37   119.402582               5.159687e-03             0.158
# 38   154.974859               1.922963e-01             0.145
# 39   117.628118               3.673458e-02             0.160
# 40   157.465849               2.102769e-01             0.163
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 37     Обучение на среднем ЭЛО по 3 кластеру
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
#
# [67 rows x 6 columns]

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_1 = xgb_pred1 + xgb_pred2/2
black_elos_1 = xgb_pred1-xgb_pred2/2
pred_elos1=list(zip(white_elos_1,black_elos_1))
print(len(pred_elos1))
pred_elos1[:5]
# Out:
# 1279
# [(498.70258, -497.70258),
#  (92.73105, -91.73105),
#  (643.60516, -642.60516),
#  (350.47534, -349.47534),
#  (-168.89972, 169.89972)]

# %%
find_abs_error(pred_elos1,elos_1),find_mean_error(pred_elos1,elos_1),find_root_mean_squared_error(pred_elos1,elos_1)
# Out:
# (4751046.0, 1857.328, 1895.49)

# %%
inner_mae_1=find_mean_error(pred_elos1,elos_1)

# %%
errors =errors.append(pd.Series(['1 кластер','XGBoost',
                  find_abs_error(pred_elos1,elos_1),
                  find_mean_error(pred_elos1,elos_1),
                   find_root_mean_squared_error(pred_elos1,elos_1) ],
                                   index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE        RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06   134.93600   168.90800
# 1      2 кластер  LinearRegression       1.566282e+06    95.28400   117.43700
# 2      3 кластер  LinearRegression       1.127526e+06    94.55900   115.89300
# 3      4 кластер  LinearRegression       1.099642e+06    94.60100   116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06   104.84500   129.63325
# 5      1 кластер     Random Forest       4.042465e+05   158.03200   195.80200
# 6      2 кластер     Random Forest       3.344622e+06   678.14700   893.17400
# 7      3 кластер     Random Forest       3.570672e+05    99.79500   122.90600
# 8      4 кластер     Random Forest       3.539965e+05   101.49000   125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06   259.36600   334.37800
# 10     1 кластер          AdaBoost       4.870781e+05   190.41400   246.69200
# 11     2 кластер          AdaBoost       3.521219e+06   713.95400   934.84000
# 12     3 кластер          AdaBoost       3.667591e+05   102.50400   126.69600
# 13     4 кластер          AdaBoost       3.640111e+05   104.36100   128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06   277.80825   359.29500
# 15     1 кластер       Extra Trees       4.225951e+05   165.20500   204.97800
# 16     2 кластер       Extra Trees       3.367925e+06   682.87200   897.57900
# 17     3 кластер       Extra Trees       3.676035e+05   102.74000   126.27200
# 18     4 кластер       Extra Trees       3.628531e+05   104.02900   128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06   263.71150   339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 25     1 кластер               SVM       3.906732e+05   152.72600   193.32600
# 26     2 кластер               SVM       3.269404e+06   662.89600   873.15100
# 27     3 кластер               SVM       3.537359e+05    98.86400   121.66600
# 28     4 кластер               SVM       3.496445e+05   100.24200   124.08000
# 29  Общая ошибка               SVM       1.090864e+06   253.68200   328.05575
# 30     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 31     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 32     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 33     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 34  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 35     1 кластер        ElasticNet       5.307052e+05   207.46900   262.47500
# 36     2 кластер        ElasticNet       3.476441e+06   704.87400   907.80400
# 37     3 кластер        ElasticNet       6.368328e+05   177.98600   236.03300
# 38     4 кластер        ElasticNet       8.465430e+05   242.70200  2524.96700
# 39  Общая ошибка        ElasticNet       1.372630e+06   333.25775   982.81975
# 40     1 кластер           XGBoost       4.751046e+06  1857.32800  1895.49000

# %%
errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)

# %% [markdown]
# ### Подбор модели для 2 кластера

# %%
start3 = time.time()

xgb3=model_mean.fit(X_train_mean_2,Y_train_mean_2)
xgb_pred3=xgb3.predict(X_test_mean_2)
scores3=predictions_report(Y_test_mean_2,xgb_pred3)
full_time3=round(time.time() - start3,3)
print(full_time3, 'c')
# Out:
# MAE = 2493.229
# RMSE = 2495.105
# Correlation coefficient = nan
# 0.319 c
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores3[0],scores3[1], 
                                 scores3[2][0],full_time3,'Обучение на среднем ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 38  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 38   154.974859               1.922963e-01             0.145
# 39   117.628118               3.673458e-02             0.160
# 40   157.465849               2.102769e-01             0.163
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
# 67  2495.104839                        NaN             0.319
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 38     Обучение на разнице ЭЛО по 3 кластеру
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
#
# [68 rows x 6 columns]

# %%
start4 = time.time()

xgb4=model_diff.fit(X_train_diff_2,Y_train_diff_2)
xgb_pred4=xgb4.predict(X_test_mean_2)
scores4=predictions_report(Y_test_diff_2,xgb_pred4)
full_time4=round(time.time() - start4,3)
print(full_time4, 'c')
# Out:
# MAE = 293.331
# RMSE = 367.956
# Correlation coefficient = 0.110
# 2.117 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores4[0],scores4[1], 
                                 scores4[2][0],full_time4,'Обучение на разнице ЭЛО по 2 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 39  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
# 68  XGBRegressor(base_score=0.5, booster='gbtree',...   293.331081
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 39   117.628118               3.673458e-02             0.160
# 40   157.465849               2.102769e-01             0.163
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
# 67  2495.104839                        NaN             0.319
# 68   367.956268               1.099148e-01             2.117
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 39     Обучение на среднем ЭЛО по 4 кластеру
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
# 68     Обучение на разнице ЭЛО по 2 кластеру
#
# [69 rows x 6 columns]

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_2 = xgb_pred3 + xgb_pred3/2
black_elos_2 = xgb_pred3-xgb_pred4/2
pred_elos2=list(zip(white_elos_2,black_elos_2))
print(len(pred_elos2))
pred_elos2[:5]
# Out:
# 2466
# [(0.75, 1.1934633),
#  (0.75, 189.29146),
#  (0.75, -237.21658),
#  (0.75, -173.44075),
#  (0.75, 68.63954)]

# %%
find_abs_error(pred_elos2,elos_2),find_mean_error(pred_elos2,elos_2),find_root_mean_squared_error(pred_elos2,elos_2)
# Out:
# (12308305.698, 2495.601, 2501.703)

# %%
inner_mae_2=find_mean_error(pred_elos2,elos_2)

# %%
errors =errors.append(pd.Series(['2 кластер','XGBoost',
                        find_abs_error(pred_elos2,elos_2),
                        find_mean_error(pred_elos2,elos_2),
                        find_root_mean_squared_error(pred_elos2,elos_2)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE        RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06   134.93600   168.90800
# 1      2 кластер  LinearRegression       1.566282e+06    95.28400   117.43700
# 2      3 кластер  LinearRegression       1.127526e+06    94.55900   115.89300
# 3      4 кластер  LinearRegression       1.099642e+06    94.60100   116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06   104.84500   129.63325
# 5      1 кластер     Random Forest       4.042465e+05   158.03200   195.80200
# 6      2 кластер     Random Forest       3.344622e+06   678.14700   893.17400
# 7      3 кластер     Random Forest       3.570672e+05    99.79500   122.90600
# 8      4 кластер     Random Forest       3.539965e+05   101.49000   125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06   259.36600   334.37800
# 10     1 кластер          AdaBoost       4.870781e+05   190.41400   246.69200
# 11     2 кластер          AdaBoost       3.521219e+06   713.95400   934.84000
# 12     3 кластер          AdaBoost       3.667591e+05   102.50400   126.69600
# 13     4 кластер          AdaBoost       3.640111e+05   104.36100   128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06   277.80825   359.29500
# 15     1 кластер       Extra Trees       4.225951e+05   165.20500   204.97800
# 16     2 кластер       Extra Trees       3.367925e+06   682.87200   897.57900
# 17     3 кластер       Extra Trees       3.676035e+05   102.74000   126.27200
# 18     4 кластер       Extra Trees       3.628531e+05   104.02900   128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06   263.71150   339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 25     1 кластер               SVM       3.906732e+05   152.72600   193.32600
# 26     2 кластер               SVM       3.269404e+06   662.89600   873.15100
# 27     3 кластер               SVM       3.537359e+05    98.86400   121.66600
# 28     4 кластер               SVM       3.496445e+05   100.24200   124.08000
# 29  Общая ошибка               SVM       1.090864e+06   253.68200   328.05575
# 30     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 31     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 32     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 33     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 34  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 35     1 кластер        ElasticNet       5.307052e+05   207.46900   262.47500
# 36     2 кластер        ElasticNet       3.476441e+06   704.87400   907.80400
# 37     3 кластер        ElasticNet       6.368328e+05   177.98600   236.03300
# 38     4 кластер        ElasticNet       8.465430e+05   242.70200  2524.96700
# 39  Общая ошибка        ElasticNet       1.372630e+06   333.25775   982.81975
# 40     1 кластер           XGBoost       4.751046e+06  1857.32800  1895.49000
# 41     2 кластер           XGBoost       1.230831e+07  2495.60100  2501.70300

# %% [markdown]
# ### Подбор модели для 3 кластера

# %%
start5 = time.time()

xgb5=model_mean.fit(X_train_mean_3,Y_train_mean_3)
xgb_pred5=xgb5.predict(X_test_mean_3)
scores5=predictions_report(Y_test_mean_3,xgb_pred5)
full_time5=round(time.time() - start5,3)
print(full_time5, 'c')
# Out:
# MAE = 2201.438
# RMSE = 2203.601
# Correlation coefficient = nan
# 0.225 c
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores5[0],scores5[1], 
                                 scores5[2][0],full_time5,'Обучение на среднем ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 40  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
# 68  XGBRegressor(base_score=0.5, booster='gbtree',...   293.331081
# 69  XGBRegressor(base_score=0.5, booster='gbtree',...  2201.437954
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 40   157.465849               2.102769e-01             0.163
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
# 67  2495.104839                        NaN             0.319
# 68   367.956268               1.099148e-01             2.117
# 69  2203.600736                        NaN             0.225
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 40     Обучение на разнице ЭЛО по 4 кластеру
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
# 68     Обучение на разнице ЭЛО по 2 кластеру
# 69     Обучение на среднем ЭЛО по 3 кластеру
#
# [70 rows x 6 columns]

# %%
start6 = time.time()

xgb6=model_diff.fit(X_train_diff_3,Y_train_diff_3)
xgb_pred6=xgb6.predict(X_test_mean_3)
scores6=predictions_report(Y_test_diff_3,xgb_pred6)
full_time6=round(time.time() - start6,3)
print(full_time6, 'c')
# Out:
# MAE = 285.467
# RMSE = 364.522
# Correlation coefficient = 0.066
# 1.383 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores6[0],scores6[1], 
                                 scores6[2][0],full_time6,'Обучение на разнице ЭЛО по 3 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 41  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   108.126575
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
# 68  XGBRegressor(base_score=0.5, booster='gbtree',...   293.331081
# 69  XGBRegressor(base_score=0.5, booster='gbtree',...  2201.437954
# 70  XGBRegressor(base_score=0.5, booster='gbtree',...   285.466619
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 41   141.652915                        NaN             4.502
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
# 67  2495.104839                        NaN             0.319
# 68   367.956268               1.099148e-01             2.117
# 69  2203.600736                        NaN             0.225
# 70   364.522038               6.642967e-02             1.383
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 41     Обучение на среднем ЭЛО по 1 кластеру
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
# 68     Обучение на разнице ЭЛО по 2 кластеру
# 69     Обучение на среднем ЭЛО по 3 кластеру
# 70     Обучение на разнице ЭЛО по 3 кластеру
#
# [71 rows x 6 columns]

# %%
output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)

# %%
white_elos_3 = xgb_pred5 + xgb_pred6/2
black_elos_3 = xgb_pred5-xgb_pred6/2
pred_elos3=list(zip(white_elos_3,black_elos_3))
print(len(pred_elos3))
pred_elos3[:5]
# Out:
# 1789
# [(82.683205, -81.683205),
#  (82.8065, -81.8065),
#  (185.40605, -184.40605),
#  (277.56213, -276.56213),
#  (265.17105, -264.17105)]

# %%
find_abs_error(pred_elos3,elos_3),find_mean_error(pred_elos3,elos_3),find_root_mean_squared_error(pred_elos3,elos_3)
# Out:
# (7872189.0, 2200.165, 2210.16)

# %%
inner_mae_3=find_mean_error(pred_elos3,elos_3)

# %%
errors =errors.append(pd.Series(['3 кластер','XGBoost',
                                 find_abs_error(pred_elos3,elos_3),
                                 find_mean_error(pred_elos3,elos_3),
                                 find_root_mean_squared_error(pred_elos3,elos_3)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE        RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06   134.93600   168.90800
# 1      2 кластер  LinearRegression       1.566282e+06    95.28400   117.43700
# 2      3 кластер  LinearRegression       1.127526e+06    94.55900   115.89300
# 3      4 кластер  LinearRegression       1.099642e+06    94.60100   116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06   104.84500   129.63325
# 5      1 кластер     Random Forest       4.042465e+05   158.03200   195.80200
# 6      2 кластер     Random Forest       3.344622e+06   678.14700   893.17400
# 7      3 кластер     Random Forest       3.570672e+05    99.79500   122.90600
# 8      4 кластер     Random Forest       3.539965e+05   101.49000   125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06   259.36600   334.37800
# 10     1 кластер          AdaBoost       4.870781e+05   190.41400   246.69200
# 11     2 кластер          AdaBoost       3.521219e+06   713.95400   934.84000
# 12     3 кластер          AdaBoost       3.667591e+05   102.50400   126.69600
# 13     4 кластер          AdaBoost       3.640111e+05   104.36100   128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06   277.80825   359.29500
# 15     1 кластер       Extra Trees       4.225951e+05   165.20500   204.97800
# 16     2 кластер       Extra Trees       3.367925e+06   682.87200   897.57900
# 17     3 кластер       Extra Trees       3.676035e+05   102.74000   126.27200
# 18     4 кластер       Extra Trees       3.628531e+05   104.02900   128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06   263.71150   339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 25     1 кластер               SVM       3.906732e+05   152.72600   193.32600
# 26     2 кластер               SVM       3.269404e+06   662.89600   873.15100
# 27     3 кластер               SVM       3.537359e+05    98.86400   121.66600
# 28     4 кластер               SVM       3.496445e+05   100.24200   124.08000
# 29  Общая ошибка               SVM       1.090864e+06   253.68200   328.05575
# 30     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 31     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 32     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 33     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 34  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 35     1 кластер        ElasticNet       5.307052e+05   207.46900   262.47500
# 36     2 кластер        ElasticNet       3.476441e+06   704.87400   907.80400
# 37     3 кластер        ElasticNet       6.368328e+05   177.98600   236.03300
# 38     4 кластер        ElasticNet       8.465430e+05   242.70200  2524.96700
# 39  Общая ошибка        ElasticNet       1.372630e+06   333.25775   982.81975
# 40     1 кластер           XGBoost       4.751046e+06  1857.32800  1895.49000
# 41     2 кластер           XGBoost       1.230831e+07  2495.60100  2501.70300
# 42     3 кластер           XGBoost       7.872189e+06  2200.16500  2210.16000

# %% [markdown]
# ### Подбор модели для 4 кластера

# %%
start7 = time.time()

xgb7=model_mean.fit(X_train_mean_4,Y_train_mean_4)
xgb_pred7=xgb7.predict(X_test_mean_4)
scores7=predictions_report(Y_test_mean_4,xgb_pred7)
full_time7=round(time.time() - start7,3)
print(full_time7, 'c')
# Out:
# MAE = 2210.197
# RMSE = 2212.325
# Correlation coefficient = nan
# 0.217 c
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
output = output.append(pd.Series([str(model_mean),
                                 scores7[0],scores7[1], 
                                 scores7[2][0],full_time7,'Обучение на среднем ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 42  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   224.492744
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
# 68  XGBRegressor(base_score=0.5, booster='gbtree',...   293.331081
# 69  XGBRegressor(base_score=0.5, booster='gbtree',...  2201.437954
# 70  XGBRegressor(base_score=0.5, booster='gbtree',...   285.466619
# 71  XGBRegressor(base_score=0.5, booster='gbtree',...  2210.196674
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684               3.101891e-01             0.026
# 1    218.061005               5.649173e-01             0.032
# 2     95.797568               2.175725e-01             0.040
# 3    135.853982               5.015886e-01             0.039
# 4     94.974990               2.378129e-01             0.040
# 5    132.827010               3.901095e-01             0.028
# 6     94.829941               2.286831e-01             0.028
# 7    134.630404               4.048796e-01             0.037
# 8    132.042952               2.695258e-01            15.508
# 9    229.315473               5.273697e-01             7.519
# 10    94.899905               1.969347e-01            35.547
# 11   142.274351               4.639618e-01            24.118
# 12    96.557585               1.491770e-01            25.474
# 13   137.163947               3.677896e-01            13.734
# 14    96.617983               1.099377e-01            21.127
# 15   137.892647               3.860759e-01            13.272
# 16   193.350924               9.402648e-02            11.439
# 17   193.350924               9.402648e-02            11.205
# 18   239.085315               4.411977e-01             1.771
# 19   104.757972               1.155195e-01            34.275
# 20   149.883409               3.957288e-01             3.448
# 21    97.541636               1.306815e-01            23.751
# 22   148.493845               1.617992e-01             2.169
# 23    98.517209               2.895609e-02            23.867
# 24   140.256347               3.023271e-01             2.246
# 25   133.103928               2.439675e-01           609.683
# 26   221.421097               5.423671e-01           441.770
# 27    95.555050               1.742332e-01          1328.309
# 28   136.596378               4.955065e-01          1268.388
# 29    96.627399               1.498900e-01           892.593
# ..          ...                        ...               ...
# 42   263.467992               4.993194e-17             5.053
# 43    98.049764              -4.655160e-02            16.371
# 44   157.256146               1.330685e-02            16.042
# 45    97.613693               3.165276e-03             6.731
# 46   145.735266               7.482165e-04             6.693
# 47    97.197577              -1.473657e-02             6.398
# 48   147.937638               1.381398e-02             6.553
# 49   168.964180              -1.168850e-02             0.137
# 50   272.234883               2.793407e-01             0.144
# 51   120.113983              -1.899401e-03             0.182
# 52   162.911876               2.896413e-01             0.302
# 53   119.402582               5.159687e-03             0.169
# 54   154.974859               1.922963e-01             0.165
# 55   117.628118               3.673458e-02             0.169
# 56   157.465849               2.102769e-01             0.156
# 57   203.877190               7.552334e-02             0.686
# 58   229.605103               4.987450e-01             0.515
# 59   246.810928              -2.958557e-02             0.969
# 60   138.832056               4.700980e-01             1.053
# 61   217.832931               3.867703e-02             0.780
# 62   136.901532               3.338479e-01             0.813
# 63  2517.134124              -1.906097e-02             0.573
# 64   417.169003               3.326434e-02             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578               1.175238e-01             1.270
# 67  2495.104839                        NaN             0.319
# 68   367.956268               1.099148e-01             2.117
# 69  2203.600736                        NaN             0.225
# 70   364.522038               6.642967e-02             1.383
# 71  2212.325449                        NaN             0.217
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 42     Обучение на разнице ЭЛО по 1 кластеру
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
# 68     Обучение на разнице ЭЛО по 2 кластеру
# 69     Обучение на среднем ЭЛО по 3 кластеру
# 70     Обучение на разнице ЭЛО по 3 кластеру
# 71     Обучение на среднем ЭЛО по 4 кластеру
#
# [72 rows x 6 columns]

# %%
start8 = time.time()

xgb8=model_diff.fit(X_train_diff_4,Y_train_diff_4)
xgb_pred8=xgb8.predict(X_test_mean_4)
scores8=predictions_report(Y_test_diff_4,xgb_pred8)
full_time8=round(time.time() - start8,3)
print(full_time8, 'c')
# Out:
# MAE = 315.061
# RMSE = 394.863
# Correlation coefficient = 0.068
# 1.768 c

# %%
output = output.append(pd.Series([str(model_diff),
                                 scores8[0],scores8[1], 
                                 scores8[2][0],full_time8,'Обучение на разнице ЭЛО по 4 кластеру'],
                                 index=output.columns ),
                      ignore_index=True)


output.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_results.xlsx',index=False)
output
# Out:
#                                                Модель          MAE  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   102.980777
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...   173.676816
# 2   LinearRegression(copy_X=True, fit_intercept=Tr...    77.387126
# 3   LinearRegression(copy_X=True, fit_intercept=Tr...   108.608625
# 4   LinearRegression(copy_X=True, fit_intercept=Tr...    80.616755
# 5   LinearRegression(copy_X=True, fit_intercept=Tr...   102.869006
# 6   LinearRegression(copy_X=True, fit_intercept=Tr...    80.319818
# 7   LinearRegression(copy_X=True, fit_intercept=Tr...   103.741893
# 8   RandomForestRegressor(bootstrap=False, criteri...   106.924601
# 9   RandomForestRegressor(bootstrap=True, criterio...   188.770360
# 10  RandomForestRegressor(bootstrap=False, criteri...    77.401777
# 11  RandomForestRegressor(bootstrap=True, criterio...   114.877201
# 12  RandomForestRegressor(bootstrap=False, criteri...    82.135211
# 13  RandomForestRegressor(bootstrap=True, criterio...   105.325596
# 14  RandomForestRegressor(bootstrap=False, criteri...    82.580581
# 15  RandomForestRegressor(bootstrap=True, criterio...   104.476313
# 16  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 17  AdaBoostRegressor(base_estimator=None, learnin...   142.565262
# 18  AdaBoostRegressor(base_estimator=None, learnin...   193.257287
# 19  AdaBoostRegressor(base_estimator=None, learnin...    88.687588
# 20  AdaBoostRegressor(base_estimator=None, learnin...   119.551083
# 21  AdaBoostRegressor(base_estimator=None, learnin...    82.589497
# 22  AdaBoostRegressor(base_estimator=None, learnin...   111.373776
# 23  AdaBoostRegressor(base_estimator=None, learnin...    84.292219
# 24  AdaBoostRegressor(base_estimator=None, learnin...   107.480968
# 25  ExtraTreesRegressor(bootstrap=False, criterion...   108.276760
# 26  ExtraTreesRegressor(bootstrap=False, criterion...   177.682547
# 27  ExtraTreesRegressor(bootstrap=False, criterion...    78.237451
# 28  ExtraTreesRegressor(bootstrap=False, criterion...   109.402946
# 29  ExtraTreesRegressor(bootstrap=False, criterion...    82.136358
# ..                                                ...          ...
# 43  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    77.803844
# 44  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   128.099075
# 45  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    83.554723
# 46  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.496710
# 47  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    82.823595
# 48  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   111.114220
# 49  KNeighborsRegressor(algorithm='auto', leaf_siz...   133.708909
# 50  KNeighborsRegressor(algorithm='auto', leaf_siz...   221.114934
# 51  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.565813
# 52  KNeighborsRegressor(algorithm='auto', leaf_siz...   129.531225
# 53  KNeighborsRegressor(algorithm='auto', leaf_siz...    97.339096
# 54  KNeighborsRegressor(algorithm='auto', leaf_siz...   121.579094
# 55  KNeighborsRegressor(algorithm='auto', leaf_siz...    95.921131
# 56  KNeighborsRegressor(algorithm='auto', leaf_siz...   122.630925
# 57  ElasticNet(alpha=1, copy_X=True, fit_intercept...   162.004084
# 58  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   181.049543
# 59  ElasticNet(alpha=1, copy_X=True, fit_intercept...   188.658497
# 60  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   111.253425
# 61  ElasticNet(alpha=1, copy_X=True, fit_intercept...   160.661907
# 62  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   107.491377
# 63  ElasticNet(alpha=1, copy_X=True, fit_intercept...   231.764518
# 64  ElasticNet(alpha=0.5, copy_X=True, fit_interce...   113.869647
# 65  XGBRegressor(base_score=0.5, booster='gbtree',...  1858.638389
# 66  XGBRegressor(base_score=0.5, booster='gbtree',...   533.074671
# 67  XGBRegressor(base_score=0.5, booster='gbtree',...  2493.228710
# 68  XGBRegressor(base_score=0.5, booster='gbtree',...   293.331081
# 69  XGBRegressor(base_score=0.5, booster='gbtree',...  2201.437954
# 70  XGBRegressor(base_score=0.5, booster='gbtree',...   285.466619
# 71  XGBRegressor(base_score=0.5, booster='gbtree',...  2210.196674
# 72  XGBRegressor(base_score=0.5, booster='gbtree',...   315.060737
#
#            RMSE  Коэффициент корр. Пирсона  Время работы (c)  \
# 0    129.002684                   0.310189             0.026
# 1    218.061005                   0.564917             0.032
# 2     95.797568                   0.217573             0.040
# 3    135.853982                   0.501589             0.039
# 4     94.974990                   0.237813             0.040
# 5    132.827010                   0.390109             0.028
# 6     94.829941                   0.228683             0.028
# 7    134.630404                   0.404880             0.037
# 8    132.042952                   0.269526            15.508
# 9    229.315473                   0.527370             7.519
# 10    94.899905                   0.196935            35.547
# 11   142.274351                   0.463962            24.118
# 12    96.557585                   0.149177            25.474
# 13   137.163947                   0.367790            13.734
# 14    96.617983                   0.109938            21.127
# 15   137.892647                   0.386076            13.272
# 16   193.350924                   0.094026            11.439
# 17   193.350924                   0.094026            11.205
# 18   239.085315                   0.441198             1.771
# 19   104.757972                   0.115520            34.275
# 20   149.883409                   0.395729             3.448
# 21    97.541636                   0.130682            23.751
# 22   148.493845                   0.161799             2.169
# 23    98.517209                   0.028956            23.867
# 24   140.256347                   0.302327             2.246
# 25   133.103928                   0.243967           609.683
# 26   221.421097                   0.542367           441.770
# 27    95.555050                   0.174233          1328.309
# 28   136.596378                   0.495507          1268.388
# 29    96.627399                   0.149890           892.593
# ..          ...                        ...               ...
# 43    98.049764                  -0.046552            16.371
# 44   157.256146                   0.013307            16.042
# 45    97.613693                   0.003165             6.731
# 46   145.735266                   0.000748             6.693
# 47    97.197577                  -0.014737             6.398
# 48   147.937638                   0.013814             6.553
# 49   168.964180                  -0.011688             0.137
# 50   272.234883                   0.279341             0.144
# 51   120.113983                  -0.001899             0.182
# 52   162.911876                   0.289641             0.302
# 53   119.402582                   0.005160             0.169
# 54   154.974859                   0.192296             0.165
# 55   117.628118                   0.036735             0.169
# 56   157.465849                   0.210277             0.156
# 57   203.877190                   0.075523             0.686
# 58   229.605103                   0.498745             0.515
# 59   246.810928                  -0.029586             0.969
# 60   138.832056                   0.470098             1.053
# 61   217.832931                   0.038677             0.780
# 62   136.901532                   0.333848             0.813
# 63  2517.134124                  -0.019061             0.573
# 64   417.169003                   0.033264             0.643
# 65  1863.674886                        NaN             0.216
# 66   668.592578                   0.117524             1.270
# 67  2495.104839                        NaN             0.319
# 68   367.956268                   0.109915             2.117
# 69  2203.600736                        NaN             0.225
# 70   364.522038                   0.066430             1.383
# 71  2212.325449                        NaN             0.217
# 72   394.862940                   0.067960             1.768
#
#                                  Комментарий
# 0      Обучение на среднем ЭЛО по кластеру 1
# 1      Обучение на разнице ЭЛО по начинающим
# 2      Обучение на среднем ЭЛО по 1 кластеру
# 3   Обучение на разнице в  ЭЛО по 2 кластеру
# 4      Обучение на среднем ЭЛО по 3 кластеру
# 5   Обучение на разнице в  ЭЛО по 3 кластеру
# 6      Обучение на среднем ЭЛО по 4 кластеру
# 7   Обучение на разнице в  ЭЛО по 4 кластеру
# 8      Обучение на среднем ЭЛО по 1 кластеру
# 9      Обучение на разнице ЭЛО по 1 кластеру
# 10     Обучение на среднем ЭЛО по 2 кластеру
# 11     Обучение на разнице ЭЛО по 2 кластеру
# 12     Обучение на среднем ЭЛО по 3 кластеру
# 13     Обучение на разнице ЭЛО по 3 кластеру
# 14     Обучение на среднем ЭЛО по 4 кластеру
# 15     Обучение на разнице ЭЛО по 4 кластеру
# 16     Обучение на среднем ЭЛО по начинающим
# 17     Обучение на среднем ЭЛО по 1 кластеру
# 18     Обучение на разнице ЭЛО по 1 кластеру
# 19     Обучение на среднем ЭЛО по 2 кластеру
# 20     Обучение на разнице ЭЛО по 2 кластеру
# 21     Обучение на среднем ЭЛО по 3 кластеру
# 22     Обучение на разнице ЭЛО по 3 кластеру
# 23     Обучение на среднем ЭЛО по 4 кластеру
# 24     Обучение на разнице ЭЛО по 4 кластеру
# 25     Обучение на среднем ЭЛО по 1 кластеру
# 26     Обучение на разнице ЭЛО по 1 кластеру
# 27     Обучение на среднем ЭЛО по 2 кластеру
# 28     Обучение на разнице ЭЛО по 2 кластеру
# 29     Обучение на среднем ЭЛО по 3 кластеру
# ..                                       ...
# 43     Обучение на среднем ЭЛО по 2 кластеру
# 44     Обучение на разнице ЭЛО по 2 кластеру
# 45     Обучение на среднем ЭЛО по 3 кластеру
# 46     Обучение на разнице ЭЛО по 3 кластеру
# 47     Обучение на среднем ЭЛО по 4 кластеру
# 48     Обучение на разнице ЭЛО по 4 кластеру
# 49     Обучение на среднем ЭЛО по 1 кластеру
# 50     Обучение на разнице ЭЛО по 1 кластеру
# 51     Обучение на среднем ЭЛО по 2 кластеру
# 52     Обучение на разнице ЭЛО по 2 кластеру
# 53     Обучение на среднем ЭЛО по 3 кластеру
# 54     Обучение на разнице ЭЛО по 3 кластеру
# 55     Обучение на среднем ЭЛО по 4 кластеру
# 56     Обучение на разнице ЭЛО по 4 кластеру
# 57     Обучение на среднем ЭЛО по 1 кластеру
# 58     Обучение на разнице ЭЛО по 1 кластеру
# 59     Обучение на среднем ЭЛО по 2 кластеру
# 60     Обучение на разнице ЭЛО по 2 кластеру
# 61     Обучение на среднем ЭЛО по 3 кластеру
# 62     Обучение на разнице ЭЛО по 3 кластеру
# 63     Обучение на среднем ЭЛО по 4 кластеру
# 64     Обучение на разнице ЭЛО по 4 кластеру
# 65     Обучение на среднем ЭЛО по 1 кластеру
# 66     Обучение на разнице ЭЛО по 1 кластеру
# 67     Обучение на среднем ЭЛО по 2 кластеру
# 68     Обучение на разнице ЭЛО по 2 кластеру
# 69     Обучение на среднем ЭЛО по 3 кластеру
# 70     Обучение на разнице ЭЛО по 3 кластеру
# 71     Обучение на среднем ЭЛО по 4 кластеру
# 72     Обучение на разнице ЭЛО по 4 кластеру
#
# [73 rows x 6 columns]

# %%
white_elos_4 = xgb_pred7 + xgb_pred8/2
black_elos_4 = xgb_pred7-xgb_pred8/2
pred_elos4=list(zip(white_elos_4,black_elos_4))
print(len(pred_elos4))
pred_elos4[:5]
# Out:
# 1744
# [(-1.4730835, 2.4730835),
#  (-268.61786, 269.61786),
#  (-353.3652, 354.3652),
#  (-196.66043, 197.66043),
#  (-305.76248, 306.76248)]

# %%
find_abs_error(pred_elos4,elos_4),find_mean_error(pred_elos4,elos_4),find_root_mean_squared_error(pred_elos4,elos_4)
# Out:
# (7715749.0, 2212.084, 2223.747)

# %%
inner_mae_4=find_mean_error(pred_elos4,elos_4)

# %%
errors =errors.append(pd.Series(['4 кластер','XGBoost',find_abs_error(pred_elos4,elos_4),
                                 find_mean_error(pred_elos4,elos_4),
                                 find_root_mean_squared_error(pred_elos4,elos_4)],
                                index=errors.columns ),
                      ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE        RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06   134.93600   168.90800
# 1      2 кластер  LinearRegression       1.566282e+06    95.28400   117.43700
# 2      3 кластер  LinearRegression       1.127526e+06    94.55900   115.89300
# 3      4 кластер  LinearRegression       1.099642e+06    94.60100   116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06   104.84500   129.63325
# 5      1 кластер     Random Forest       4.042465e+05   158.03200   195.80200
# 6      2 кластер     Random Forest       3.344622e+06   678.14700   893.17400
# 7      3 кластер     Random Forest       3.570672e+05    99.79500   122.90600
# 8      4 кластер     Random Forest       3.539965e+05   101.49000   125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06   259.36600   334.37800
# 10     1 кластер          AdaBoost       4.870781e+05   190.41400   246.69200
# 11     2 кластер          AdaBoost       3.521219e+06   713.95400   934.84000
# 12     3 кластер          AdaBoost       3.667591e+05   102.50400   126.69600
# 13     4 кластер          AdaBoost       3.640111e+05   104.36100   128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06   277.80825   359.29500
# 15     1 кластер       Extra Trees       4.225951e+05   165.20500   204.97800
# 16     2 кластер       Extra Trees       3.367925e+06   682.87200   897.57900
# 17     3 кластер       Extra Trees       3.676035e+05   102.74000   126.27200
# 18     4 кластер       Extra Trees       3.628531e+05   104.02900   128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06   263.71150   339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 25     1 кластер               SVM       3.906732e+05   152.72600   193.32600
# 26     2 кластер               SVM       3.269404e+06   662.89600   873.15100
# 27     3 кластер               SVM       3.537359e+05    98.86400   121.66600
# 28     4 кластер               SVM       3.496445e+05   100.24200   124.08000
# 29  Общая ошибка               SVM       1.090864e+06   253.68200   328.05575
# 30     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 31     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 32     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 33     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 34  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 35     1 кластер        ElasticNet       5.307052e+05   207.46900   262.47500
# 36     2 кластер        ElasticNet       3.476441e+06   704.87400   907.80400
# 37     3 кластер        ElasticNet       6.368328e+05   177.98600   236.03300
# 38     4 кластер        ElasticNet       8.465430e+05   242.70200  2524.96700
# 39  Общая ошибка        ElasticNet       1.372630e+06   333.25775   982.81975
# 40     1 кластер           XGBoost       4.751046e+06  1857.32800  1895.49000
# 41     2 кластер           XGBoost       1.230831e+07  2495.60100  2501.70300
# 42     3 кластер           XGBoost       7.872189e+06  2200.16500  2210.16000
# 43     4 кластер           XGBoost       7.715749e+06  2212.08400  2223.74700

# %%
xgb_mae=(inner_mae_4+inner_mae_3+inner_mae_2+inner_mae_1)/4
xgb_mae
# Out:
# 2191.2945

# %%
xgb_abs=(find_abs_error(pred_elos1,elos_1)+
        find_abs_error(pred_elos2,elos_2)+
        find_abs_error(pred_elos3,elos_3)+
        find_abs_error(pred_elos4,elos_4))/4
xgb_abs
# Out:
# 8161822.4245

# %%
xgb_rmse=(find_root_mean_squared_error(pred_elos1,elos_1)+
         find_root_mean_squared_error(pred_elos2,elos_2)+
         find_root_mean_squared_error(pred_elos3,elos_3)+
         find_root_mean_squared_error(pred_elos4,elos_4))/4
xgb_rmse
# Out:
# 2207.775

# %%
errors = errors.append(pd.Series(['Общая ошибка','XGBoost',
                  xgb_abs,
                  xgb_mae,
                 xgb_rmse],index=errors.columns) ,ignore_index=True)

errors.to_excel(r'C:\Users\Asus\PredictingRatings\models\class_errors.xlsx',index=False)
errors
# Out:
#           Группа            Модель  Абсолютная ошибка         MAE        RMSE
# 0      1 Кластер  LinearRegression       1.150193e+06   134.93600   168.90800
# 1      2 кластер  LinearRegression       1.566282e+06    95.28400   117.43700
# 2      3 кластер  LinearRegression       1.127526e+06    94.55900   115.89300
# 3      4 кластер  LinearRegression       1.099642e+06    94.60100   116.29500
# 4   Общая ошибка  LinearRegression       1.235911e+06   104.84500   129.63325
# 5      1 кластер     Random Forest       4.042465e+05   158.03200   195.80200
# 6      2 кластер     Random Forest       3.344622e+06   678.14700   893.17400
# 7      3 кластер     Random Forest       3.570672e+05    99.79500   122.90600
# 8      4 кластер     Random Forest       3.539965e+05   101.49000   125.63000
# 9   Общая ошибка     Random Forest       1.114983e+06   259.36600   334.37800
# 10     1 кластер          AdaBoost       4.870781e+05   190.41400   246.69200
# 11     2 кластер          AdaBoost       3.521219e+06   713.95400   934.84000
# 12     3 кластер          AdaBoost       3.667591e+05   102.50400   126.69600
# 13     4 кластер          AdaBoost       3.640111e+05   104.36100   128.95200
# 14  Общая ошибка          AdaBoost       1.184767e+06   277.80825   359.29500
# 15     1 кластер       Extra Trees       4.225951e+05   165.20500   204.97800
# 16     2 кластер       Extra Trees       3.367925e+06   682.87200   897.57900
# 17     3 кластер       Extra Trees       3.676035e+05   102.74000   126.27200
# 18     4 кластер       Extra Trees       3.628531e+05   104.02900   128.15800
# 19  Общая ошибка       Extra Trees       1.130244e+06   263.71150   339.24675
# 20     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 21     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 22     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 23     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 24  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 25     1 кластер               SVM       3.906732e+05   152.72600   193.32600
# 26     2 кластер               SVM       3.269404e+06   662.89600   873.15100
# 27     3 кластер               SVM       3.537359e+05    98.86400   121.66600
# 28     4 кластер               SVM       3.496445e+05   100.24200   124.08000
# 29  Общая ошибка               SVM       1.090864e+06   253.68200   328.05575
# 30     1 кластер       K-Neighbors       4.714090e+05   184.28800   231.23100
# 31     2 кластер       K-Neighbors       3.390598e+06   687.46900   897.82200
# 32     3 кластер       K-Neighbors       4.156099e+05   116.15700   144.31700
# 33     4 кластер       K-Neighbors       4.206438e+05   120.59700   150.04800
# 34  Общая ошибка       K-Neighbors       1.174565e+06   277.12775   355.85450
# 35     1 кластер        ElasticNet       5.307052e+05   207.46900   262.47500
# 36     2 кластер        ElasticNet       3.476441e+06   704.87400   907.80400
# 37     3 кластер        ElasticNet       6.368328e+05   177.98600   236.03300
# 38     4 кластер        ElasticNet       8.465430e+05   242.70200  2524.96700
# 39  Общая ошибка        ElasticNet       1.372630e+06   333.25775   982.81975
# 40     1 кластер           XGBoost       4.751046e+06  1857.32800  1895.49000
# 41     2 кластер           XGBoost       1.230831e+07  2495.60100  2501.70300
# 42     3 кластер           XGBoost       7.872189e+06  2200.16500  2210.16000
# 43     4 кластер           XGBoost       7.715749e+06  2212.08400  2223.74700
# 44  Общая ошибка           XGBoost       8.161822e+06  2191.29450  2207.77500
